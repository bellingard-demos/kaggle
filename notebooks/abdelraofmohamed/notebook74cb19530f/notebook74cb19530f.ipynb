# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
data = pd.read_excel("/kaggle/input/trail-2/test.xlsx")
data.head(30)

# %%
import pandas as pd
import re

def extract_number_before_keyword(text, keyword):
    pattern = rf'(\d+)\s+{re.escape(keyword)}'
    match = re.search(pattern, text)
    if match:
        return match.group(1)
    else:
        return None

# Read the Excel file into a Pandas DataFrame
file_path = '/kaggle/input/trail-2/test.xlsx'
data = pd.read_excel(file_path)

# Select the column containing the text
text_column = data['ALL_PALLETS_INFO']  # Replace with your actual column name

# Keyword to find
keyword = "P-PALLET"

# Extract the number before the keyword for each text in the column
numbers = []
for t in text_column:
    number = extract_number_before_keyword(str(t), keyword)  # Ensure the text is converted to string
    numbers.append(number)

# Create a DataFrame from the extracted numbers
df = pd.DataFrame({'Extracted_Number': numbers})

print(df)

# %%
import pandas as pd
import re

def extract_number_before_keyword(text, keyword):
    pattern = rf'(\d+)\s+{re.escape(keyword)}'
    match = re.search(pattern, text)
    if match:
        return match.group(1)
    else:
        return None

# Read the Excel file into a Pandas DataFrame
file_path = '/kaggle/input/trail-2/test.xlsx'
data = pd.read_excel(file_path)

# Select the column containing the text
text_column = data['ALL_PALLETS_INFO']  # Replace with your actual column name

# Keyword to find
keyword = "P-PALLET"

# Extract the number before the keyword for each text in the column
numbers = []
for t in text_column:
    number = extract_number_before_keyword(str(t), keyword)  # Ensure the text is converted to string
    numbers.append(number)

# Replace the data inside the 'P-PALLET' column with the extracted numbers
data['P-PLALLET'] = numbers


data.head()

# %%
import pandas as pd
import re

def extract_number_before_keyword(text, keyword):
    pattern = rf'(\d+)\s+{re.escape(keyword)}'
    match = re.search(pattern, text)
    if match:
        return match.group(1)
    else:
        return None

# Read the Excel file into a Pandas DataFrame
file_path = '/kaggle/input/trail-2/test.xlsx'
data = pd.read_excel(file_path)

# Keywords to find
keywords = ["P-PALLET", "PALLET", "C-BOX"]

# Initialize columns for each keyword with NaN
for keyword in keywords:
    data[keyword] = float('NaN')

# Select the column containing the text
text_column = data['ALL_PALLETS_INFO']  # Replace with your actual column name

# Extract the number before each keyword for each text in the column
for keyword in keywords:
    numbers = []
    for t in text_column:
        number = extract_number_before_keyword(str(t), keyword)  # Ensure the text is converted to string
        numbers.append(number)
    data[keyword] = numbers

# Drop the second column (index 1)
data = data.drop(data.columns[1], axis=1)

# Re-allocate the last column to be the second one
columns = list(data.columns)
last_column = columns.pop()  # Remove the last column
columns.insert(1, last_column)  # Re-insert the last column at index 1

# Rearrange the columns in the DataFrame
data = data[columns]

data.head(50)

# %%
import pandas as pd
import re

def extract_number_before_keyword(text, keyword):
    pattern = rf'(\d+)\s+{re.escape(keyword)}'
    match = re.search(pattern, text)
    if match:
        return match.group(1)
    else:
        return None

# Read the Excel file into a Pandas DataFrame
file_path = '/kaggle/input/trail-2/test.xlsx'
data = pd.read_excel(file_path)

# Keywords to find
keywords = ["P-PALLET", "PALLET", "C-BOX"]

# Initialize columns for each keyword with NaN
for keyword in keywords:
    data[keyword] = float('NaN')

# Select the column containing the text
text_column = data['ALL_PALLETS_INFO']  # Replace with your actual column name

# Extract the number before each keyword for each text in the column
for keyword in keywords:
    numbers = []
    for t in text_column:
        number = extract_number_before_keyword(str(t), keyword)  # Ensure the text is converted to string
        numbers.append(number)
    data[keyword] = numbers

# Drop the second column (index 1)
data = data.drop(data.columns[1], axis=1)

# Re-allocate the last column to be the second one
columns = list(data.columns)
last_column = columns.pop()  # Remove the last column
columns.insert(1, last_column)  # Re-insert the last column at index 1

# Rearrange the columns in the DataFrame
data = data[columns]

data.head(50)

# Define the path to save the CSV file in the writable directory (/kaggle/working/)
csv_file_path = '/kaggle/working/data.csv'

# Save the DataFrame to a CSV file in the writable directory
data.to_csv(csv_file_path, index=False)
