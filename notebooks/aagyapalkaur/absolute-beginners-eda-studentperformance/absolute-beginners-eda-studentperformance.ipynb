# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:25px;
#            background-color:#172774;
#            font-size:210%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           text-align:center;"
#           >
#        WELCOME TO MY NOTEBOOK
# </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:25px;
#            background-color:Green;
#            font-size:160%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           text-align:center;"
#           >
#        Student Performance in Exam
# </p>
# </div>
#
# # About Dataset
# This dataset contain the information about the student performance in exam.
# This dataset consist of 8 columns:
#
# ![](https://chronicle.brightspotcdn.com/dims4/default/405b78d/2147483647/strip/true/crop/1152x648+0+0/resize/840x473!/quality/90/?url=http%3A%2F%2Fchronicle-brightspot.s3.amazonaws.com%2F78%2F79%2F1eb1ce05400391e5690e4718496b%2Fmain-gif-lr.gif)
# 1. gender: Male or Female
# 2. race: 'group A', 'group B', 'group C', 'group D', 'group E'
# 3. education : 'high school', 'some high school', 'some college',"associate's degree", "bachelor's degree", "master's degree"
# 4. lunch: 'standard', 'free/reduced'
# 5. test preparation course: 'completed', 'none'
# 6. math score: Marks earned by students in mathematics
# 7. reading score: Marks earned by students in reading
# 8. writing score: Marks earned by students in writing
#
# In this notebook we are going to perform in detail Exploratory Data Analysis.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:25px;
#            background-color:red;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           text-align:left;"
#           >
#        Importing all the necessary Libraries
# </p>
# </div>

# %%
# Import all the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:25px;
#            background-color:red;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           text-align:left;"
#           >
#        Read the Dataset
# </p>
# </div>

# %%
dataframe= pd.read_csv("/kaggle/input/students-performance-in-exams/exams.csv")
dataframe.head()

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:25px;
#            background-color:red;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           text-align:left;"
#           >
# Check the Datatypes of each column
# </p>
# </div>

# %%
dataframe.info()

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:25px;
#            background-color:red;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           text-align:left;"
#           >
# Check the shape of the dataset
# </p>
# </div>

# %%
dataframe.shape

# %%
# Getting column list
columns=dataframe.columns.tolist()
columns

# %%
# Lets make the columns name simple
columns[1]="race"
columns[2]="education"
dataframe.columns=columns
dataframe.head()

# %% [markdown]
#
#
# <div style="color:white;
#            display:fill;
#            border-radius:25px;
#            background-color:red;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           text-align:left;"
#           >
# Describe the Dataset
# </p>
# </div>

# %%
dataframe.describe()

# %% [markdown]
# > Here we can see the range minimum and maximum scores of math, reading and writing test

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:25px;
#            background-color:red;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           text-align:left;"
#           >
#     Lets check the null values in the dataset
#
# </p>
# </div>

# %%
dataframe.isnull().sum()

# %% [markdown]
# >  There is no missing value in the dataset

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:25px;
#            background-color:red;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           text-align:left;"
#           >
# Lets check the duplicate values in the dataset
# </p>
# </div>

# %%
dataframe.duplicated().sum()

# %% [markdown]
# > Dataset contain 1 duplicate value. Lets remove this duplicate value

# %%
# Remove the duplicate value from the dataset
dataframe.drop_duplicates(inplace=True)

# %%
# check again to see duplicate value is removed from the dataset 
dataframe.duplicated().sum()

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:25px;
#            background-color:red;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           text-align:left;"
#           >
#  Getting the List of Numerial and Categorical Features
# </p>
# </div>

# %%
def get_num_cat_columns(dataframe):
    categorical_cols=dataframe.select_dtypes(include="object").columns
    numerical_cols=dataframe.select_dtypes(exclude="object").columns
    
    return categorical_cols, numerical_cols

# %%
categorical_cols, numerical_cols= get_num_cat_columns(dataframe)

# %%
categorical_cols,

# %%
numerical_cols

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:25px;
#            background-color:red;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           text-align:left;"
#           >
#     Lets check the unique values in each categorical column
# </p>
# </div>

# %%
dataframe["gender"].unique()

# %%
dataframe["race"].unique()

# %%
dataframe["education"].unique()

# %%
dataframe["lunch"].unique()

# %%
dataframe["test preparation course"].unique()

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:25px;
#            background-color:red;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           text-align:left;"
#           >
#  Exploratory Data Analysis
# </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:25px;
#            background-color:red;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           text-align:left;"
#           >
#  Univariate Analysis
# </p>
# </div>
#
# > Lets see the count distribution of each column.
# > > Categorical Columns

# %%
fig = px.histogram(dataframe, x="gender", color="gender", width=800, height=500, title="Frequency Distribution of Gender")
fig.show()

# %%
fig = px.histogram(dataframe, x="race", color="race", width=800, height=500, title="Frequency Distribution of Race")
fig.show()

# %%
fig = px.histogram(dataframe, x="education", color="education", width=800, height=500, title="Frequency Distribution of Education Level ")
fig.show()

# %%
fig = px.histogram(dataframe, x="lunch", color="lunch", width=800, height=500, title="Frequency Distribution of Lunch")
fig.show()

# %%
fig = px.histogram(dataframe, x="test preparation course", color="test preparation course", width=800, height=500, title="Frequency Distribution of Test Preparation Course")
fig.show()

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:25px;
#            background-color:red;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           text-align:left;"
#           >
#  Count Distribution of Numerical Columns
# </p>
# </div>

# %%
plt.figure(figsize=(10,5))
sns.histplot(dataframe, x="math score",color="Green",kde=True)
plt.title("Data Distribution of Math Score")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(dataframe, x="reading score",color="red",kde=True)
plt.title("Data Distribution of Reading Score")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(dataframe, x="writing score",color="blue",kde=True)
plt.title("Data Distribution of Writing Score")
plt.show()

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:25px;
#            background-color:red;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           text-align:left;"
#           >
# Bivariate Analysis
# </p>
# </div>
#
# > In Bivariate Analysis we are going two comapre two features with each other.

# %%
fig = px.violin(dataframe, x="education", y="math score", color="gender", box=True, title="Impact of Education Level on Math Score considering Gender")
fig.show()

# %%
fig = px.violin(dataframe, x="education", y="reading score", color="gender", box=True, title="Impact of Education Level on Reading Score along considering Gender")
fig.show()

# %%
fig = px.violin(dataframe, x="education", y="writing score", color="gender", box=True, title="Impact of Education Level on Writing Score considering Gender")
fig.show()

# %%
fig = px.violin(dataframe, x="test preparation course", y="math score", color="gender", box=True, title="Impact of Test preparation Course on Math Score considering Gender")
fig.show()

# %%
fig = px.violin(dataframe, x="test preparation course", y="reading score", color="gender", box=True, title="Impact of Test preparation Course on Reading Score considering Gender")
fig.show()

# %%
fig = px.violin(dataframe, x="test preparation course", y="writing score", color="gender", box=True, title="Impact of Test preparation Course on Writing Score considering Gender")
fig.show()

# %%
fig = px.violin(dataframe, x="lunch", y="math score", color="gender", box=True, title="Impact of lunch on Math Score considering Gender")
fig.show()

# %%
fig = px.violin(dataframe, x="lunch", y="reading score", color="gender", box=True, title="Impact of lunch on Reading Score considering Gender")
fig.show()

# %%
fig = px.violin(dataframe, x="lunch", y="writing score", color="gender", box=True, title="Impact of lunch Course on Writing Score considering Gender")
fig.show()

# %%
plt.figure(figsize = (14,6))
sns.countplot(x=dataframe["race"], hue=dataframe["gender"], palette="bright")
plt.title("Race Data Distribution with Gender")
plt.xlabel("Race considering Gender")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# "Appreciations for delving into my Kaggle notebook! Your engagement elevates collaborative learning. Upvote to endorse the exchange of insights. Your support fuels curiosity and growth. Heartfelt thanks for being part of this knowledge expedition. 👍📚"
#
# ![](https://i.pinimg.com/originals/ec/2e/c8/ec2ec8760d3743c03ca308c79e93a6b5.gif)
