# %%
# !pip install pandasai

# %%
import pandas as pd 
import numpy as np 
from pandasai import PandasAI 
from pandasai.llm.openai import OpenAI

# %%
data=pd.read_excel("/kaggle/input/pandasdataset/02 Churn-Dataset.xlsx")
data

# %%
llm = OpenAI(api_token="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") 
pandas_ai = PandasAI(llm, conversational=False)

# %%
# finding index of a row using value of a column 
response = pandas_ai(data, "top five TotalCharges per customer") 
print(response)

# %%
response = pandas_ai(data, "create pie chart for this churn") 
print(response)

# %%
response = pandas_ai(data, "compare by chart of tenure per contract") 
print(response)
