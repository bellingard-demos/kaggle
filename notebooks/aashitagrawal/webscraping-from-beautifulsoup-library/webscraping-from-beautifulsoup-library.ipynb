# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Link to the web scraped dataset
# https://www.kaggle.com/datasets/aashitagrawal/best-books-of-21st-century-dataset

# %%
#BeautifulSoup is a very vast library for web scrapping, when you start a project if you want to learn, learn only those things that will be important for you in that project
import requests
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/113.0.5672.127 Safari/537.36'}
webpage=requests.get('https://www.goodreads.com/list/show/7.Best_Books_of_the_21st_Century?page=1', headers=headers).text
soup=BeautifulSoup(webpage,'lxml')

# %%
soup.find_all('h1')

# %%
soup.find_all('h1')[0].text.strip()

# %%
len(soup.find_all("a",class_="bookTitle"))

# %%
len(soup.find_all("a",class_="authorName"))

# %%
soup.find_all("td",class_="number")[5].text.strip()

# %%
soup.find_all("a",class_="bookTitle")[5].text.strip()

# %%
soup.find_all("a",class_="authorName")[5].text.strip()

# %%
soup.find_all("span",class_="greyText smallText uitext")[5].text.strip()

# %%
soup.find_all("span",class_="smallText uitext")[5].text.strip()

# %%
rank = []
book = []
author = []
rating = []
score = []
for j in range(0,100):
    rank.append(soup.find_all("td",class_="number")[j].text.strip())
    book.append(soup.find_all("a",class_="bookTitle")[j].text.strip())
    author.append(soup.find_all("a",class_="authorName")[j].text.strip())
    rating.append(soup.find_all("span",class_="greyText smallText uitext")[j].text.strip())
    score.append(soup.find_all("span",class_="smallText uitext")[j].text.strip())

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
rank = []
book = []
author = []
rating = []
score = []
for i in range(1,98):
    webpage=requests.get('https://www.goodreads.com/list/show/7.Best_Books_of_the_21st_Century?page={}'.format(i), headers=headers).text
    soup = BeautifulSoup(webpage,'lxml')
    for j in range(0,100):
        rank.append(soup.find_all("td",class_="number")[j].text.strip())
        book.append(soup.find_all("a",class_="bookTitle")[j].text.strip())
        author.append(soup.find_all("a",class_="authorName")[j].text.strip())
        rating.append(soup.find_all("span",class_="greyText smallText uitext")[j].text.strip())
        score.append(soup.find_all("span",class_="smallText uitext")[j].text.strip())

# %%
dict = {'rank': rank,'book':book,'author':author,'rating':rating,'score':score}
df=pd.DataFrame(dict)
df

# %% [markdown]
# # After cleaning the data
# useful functions to clean the data
#
# 1.  .reset_index()
# 2.  pd.concat
# 3.  dataframename.columnname.str.split(expand=True)
# 4.  dataframe["columnname"] = dataframe["columnname"].str.replace(',','')
# 5. .copy()

# %%
finaldata.columns = ['rank','book','author','average rating','total ratings','number of people voted','score']

# %%
finaldata

# %%
finaldata.to_csv("Best books of 21st century dataset.csv")

# %% [markdown]
# # Link to the web scraped dataset
# https://www.kaggle.com/datasets/aashitagrawal/best-books-of-21st-century-dataset

# %% [markdown]
# if you like it, please give it a upvote :)
