# %% [markdown]
# # **Abdulrahman Alhajj**
#
# ---
#
# 🟠 **Connect with me:**
#
# [![GitHub](https://img.shields.io/badge/GitHub-100000?style=for-the-badge&style=social&logo=github&logoColor=white)](https://github.com/aaaalhajoo1)
# [![Follow](https://img.shields.io/twitter/follow/aaaalhaj000?style=social)](https://www.twitter.com/aaaalhaj000)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-0077B5?style=for-the-badge&style=social&logo=linkedin&logoColor=white)](https://linkedin.com/in/abdulrahman-alhajj)
# [![Kaggle](https://img.shields.io/badge/Kaggle-20BEFF?style=for-the-badge&style=social&logo=Kaggle&logoColor=white)](https://www.kaggle.com/abdulrahmanahajj)
#
# ---

# %% [markdown]
# ![games.png](data:image/png;base64,...)

# %% [markdown]
# # **Object**
# Object this project to create a sample Exploratory Data Analysis using Python programming language and use libraries like matplotlib , pandas, and seaborn, The data used in this project contains information only from 1980 to 2020. Below is a sketch of all the stages made in these notebooks, following a logical and intuitive sequence to facilitate the understanding of the data

# %% [markdown]
# # **About Dataset**
#
# This dataset contains a list of video games with sales greater than 100,000 copies. It was generated by a scrape of vgchartz.com.
#
# **Fields include**
# <table>
#     <tr>
#         <th>#</th>
#         <th>Column Name</th>
#         <th>Description</th>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>Rank</td>
#         <td>Ranking of overall sales</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>Name</td>
#         <td>The games name</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>Platform</td>
#         <td>Platform of the games release (i.e. PC,PS4, etc.)</td>
#     </tr>
#      <tr>
#         <td>4</td>
#         <td>Year</td>
#         <td>Year of the game's release</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>Genre </td>
#         <td>Genre of the game</td>
#     </tr>
#     <tr>
#         <td>6</td>
#         <td>Publisher</td>
#         <td>Publisher of the game</td>
#     </tr>
#     <tr>
#         <td>7</td>
#         <td>NA_Sales</td>
#         <td>Sales in North America (in millions)</td>
#     </tr>
#     <tr>
#         <td>8</td>
#         <td>EU_Sales</td>
#         <td>Sales in Europe (in millions)</td>
#     </tr>
#     <tr>
#         <td>9</td>
#         <td>JP_Sales</td>
#         <td>Sales in Japan (in millions)</td>
#     </tr>
#     <tr>
#         <td>10</td>
#         <td>Other_Sales</td>
#         <td>Sales in the rest of the world (in millions)</td>
#     </tr>
#     <tr>
#         <td>11</td>
#         <td>Global_Sales</td>
#         <td>Total worldwide sales</td>
#     </tr>
#
# </table>

# %% [markdown]
# # **EDA(Exploratory Data Analysis)**
# EDA stands for Exploratory Data Analysis. It is a type of data analysis that involves exploring and summarizing data sets to gain insights into the patterns, relationships, and distributions of the data. EDA data analysis is used to identify outliers, missing values, and other anomalies in the data, as well as to identify trends and patterns that can help guide further analysis or inform decision-making. EDA data analysis can involve a range of techniques, including visualization, descriptive statistics, and statistical modeling, and is often used in fields such as data science, business analytics, and social science

# %% [markdown]
# ## **Load Necessary Libraries**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

#For display Visualization in notebooks
# %matplotlib inline

# %% [markdown]
# At first, we will use Pandas and what is panda?
#
# **Pandas:** is  is an open-source Python library that provides data manipulation and analysis tools for structured data. The main data structures provided by Pandas are Series (1-dimensional) and DataFrame (2-dimensional), which allow users to manipulate and analyze data in various ways, such as filtering, grouping, sorting, reshaping, merging, and aggregating. Pandas also supports reading and writing data in various formats, such as CSV, Excel, SQL databases, and JSON. It is widely used in data science, finance, economics, social sciences, and many other fields where data analysis is required.

# %%
#Recall import pandas as pd for use padnas
#Load data from csv file
data=pd.read_csv("/kaggle/input/videogamesales/vgsales.csv")
data.head()

# %%
#show name cloumns
data.columns

# %%
#dataset shape
data.shape

# %%
#show information in dataset name cloumn and not null and dtypes
data.info()

# %%
#show null all values
data.isnull().sum()

# %%
#drop all null value because null is small part of dataset
data=data.dropna()

# %%
#Change type  Year from float to integer
data["Year"] = data['Year'].astype(int)

# %%
#show null all values
data.isnull().sum()

# %% [markdown]
# ### **Calculate describe statistics (count , max , min , 50%,25% ,75% , mean)**
#
# Creates a new variable  called data_describe .Remove the Categorical columns ,Rank and Years.The second line of code, data_describe.describe(), prints the summary statistics of the df_describe DataFrame. The describe() method calculates the mean, standard deviation, minimum, maximum, and quartiles of the DataFrame.

# %%
data_describe=data[['NA_Sales','EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']]
data_describe.describe()

# %% [markdown]
# # **Questions**

# %% [markdown]
# These questions can be asked in exploratory data analysis and you can ask more questions

# %% [markdown]
# ## **Who are the five largest publishers in terms of the number of games?**

# %%
best_Platform=data.Platform.value_counts().nlargest(5)
best_Platform

# %% [markdown]
# ## **Who are the five smallest publishers in terms of the number of games?**

# %%
small_Platform=data.Platform.value_counts().nsmallest(5)
small_Platform

# %% [markdown]
# ## **What is sales Games  in North America Greater than 10 in millions?**

# %%
data[data.NA_Sales > 10.00]

# %% [markdown]
# ## **What is the game have Highest selling in Global Sales and what is the Platform?**

# %%
#hgs = highest_games_sell
hgs=data[["Name","Platform","Global_Sales"]]
hgs[hgs.Global_Sales==hgs.Global_Sales.max()]

# %% [markdown]
# ## **What is the games have lowest selling in Japan Sales and what is the Genre?**

# %%
#lgs = lowest_games_sell
lgs=data[data.JP_Sales==data.JP_Sales.min()]
lgs[["Name","Genre","JP_Sales"]]

# %%
lgs=data[data.JP_Sales==data.JP_Sales.min()]
lgs[["Name","Genre","JP_Sales"]]
lgs.Genre.value_counts()

# %% [markdown]
# ## **Which publisher has published the largest number of games?**

# %%
#lp = largest publisher
lp=data.Publisher.value_counts()
lp=lp.head(1)
lp

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# second, we will use matplotlib and seaborn what is matplotlib and seaborn ?
#
# **Matplotlib**: is an open-source data visualization library for Python. It provides a variety of customizable plots and charts for visualizing data in a clear and concise manner. Matplotlib can be used to create line plots, scatter plots, bar plots, histograms, 3D plots, and many other types of visualizations. integrates well with other scientific Python libraries such as Pandas and SciPy. Matplotlib can also be used to create interactive visualizations and animations. It is widely used in fields such as data science, engineering, finance, and social sciences for data exploration and presentation.
#
#
# **Seaborn**: is a Python data visualization library built on top of Matplotlib. It provides a high-level interface for creating informative and attractive statistical graphics. Seaborn includes a variety of plot types such as scatter plots, line plots, bar plots, heatmaps, and more. It also offers advanced features such as color palettes, statistical functions, and themes that make it easy to create professional-looking visualizations. Seaborn is commonly used in data science, machine learning, and statistical analysis to explore and communicate data insights.

# %% [markdown]
# ## **Sales of games from 1980 to 2020**

# %%
#Recall import seaborn as sns for use seaborn
sns.lineplot(x='Year', y='NA_Sales',data=data,label='North America')
sns.lineplot(x='Year', y='JP_Sales',data=data,label='Japan')
sns.lineplot(x='Year', y='EU_Sales',data=data,label='Europe')
#Recall import matplotlib.pyplot as plt for use matplotlib
plt.xlabel("years")
plt.title("Sales of games from 1980 to 2020")
plt.ylabel("USD in millions")
#add value in list
plt.legend()
plt.show()

# %% [markdown]
# Here I have created a line chart for game sales from 1980 to 2020 for sales in North America, sales in Europe, and sales in Japan. We note that America has the highest sales, followed by Japan, then Europe

# %% [markdown]
# ## **Correlations between features in dataset**

# %%
#Recall import seaborn as sns for use seaborn
corr_matrix = data.corr()
top_corr_features = corr_matrix.index
plt.figure(figsize=(8,6))
#plot heat map
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")
plt.title("Correlations between features in dataset")

# %% [markdown]
# Here I have created correlations for each feature in the data set except for the categorical features. We note that most of the data have a weak relationships with Rank and Yaer and strong relationships with Sales in North America, Sales in Europe,Sales in JapanSales

# %% [markdown]
# ### **What is market share for top 10 Platforms**

# %%
gradable_counts=data.Platform.value_counts().nlargest(10)
# Plot a pie chart
gradable_counts.plot(kind='pie', title='Top 10 Platforms', figsize=(8,8),autopct='%.2f %%')
plt.legend()
plt.show()

# %% [markdown]
# Here I have created a pie chart of the percentage of the top 10 selected platforms. Note the platforms DS, PS2, PS3, and Wii have the largest percentage of games, and platforms PC, XB, and GBA have the lowest  percentage of games

# %% [markdown]
# ## **What is market share for all Genre**

# %%
best_Genre=data.Genre.value_counts()
best_Genre.plot(kind='bar', title='Top Genres', figsize=(8,6))
plt.legend()
plt.show()

# %% [markdown]
# Here I have created a bar chart best Genres Note the Genres Action, Sports, and Misc have the largest number of games, and Fighting, Strategy, and Puzzle  have the lowest number of games

# %% [markdown]
# # **References**

# %% [markdown]
# To learn more you can visit matplotlib , pandas, and seaborn documentation
#
# **Matplotlib:**:https://matplotlib.org/stable/index.html
#
# **Pandas:** https://pandas.pydata.org/docs/
#
# **Seaborn:** https://seaborn.pydata.org/
