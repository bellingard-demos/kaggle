# %% [markdown]
# <div style="text-align: left; background-color:#FBF9FC; font-family: Trebuchet MS; color: #5D478B ; padding: 12px; line-height:1.25;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 48px">Car Price Prediction</div>
#
# <img src="https://giffiles.alphacoders.com/195/19550.gif" length=1000 width=1300>
#
# #
#
#
#
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#FFEECC;font-family:cursive;color:#8B8B83;font-size:200%;text-align:center;border-radius:15px 15px;"> Please Upvote my kernel if you liked it 😀</p>
#
# #

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist"></div>
#
# ## <div style="text-align: left; background-color: #CD8C95 ; font-family: Trebuchet MS; color: black; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px">TABLE OF CONTENTS📝</div>
#
# * [1. OBJECTIVES OF NOTEBOOK](#1)
#
# * [2. IMPORTING LIBRARIES](#2)
#
# * [3. LOADING DATA](#3)
#
# * [4. DATA EXPLORATORY & CLEANING](#4)
#
# * [5. DATA VISUALIZATION & ANALYSIS](#5)
#
# * [6. MAKING LINEAR REGRESSION MODEL](#6)G
#
# * [7. MAKING NONLINEAR MODEL TO ACHIVE BETTER SCORE](#7)
# * [8. CROSS VALIDATION](#8)
# * [9. SHOW PREDICTIONS](#9)

# %% [markdown]
# <a id="1"></a>
# ## <div style="text-align: left; background-color: #CD8C95 ; font-family: Trebuchet MS; color: black; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px">OBJECTIVES OF NOTEBOOK 📌</div>
# <div style="font-family: Segoe UI; line-height: 2; color:#000000 ; text-align: justify">
#     👉 <b>This notebook aims to:</b>
#     <ul>
#       <li> <mark><b>Data cleaning and preprocessing</li>
#       <li> <mark><b>    Practice using libraries to visualize data</li>
#       <li> <mark><b>Visualize data, provide explanations about the correlation between attributes</li>
#        <li> <mark><b>predict the cost of car</li>

# %% [markdown]
# <a id="2"></a>
# ## <div style="text-align: left; background-color: #CD8C95 ; font-family: Trebuchet MS; color: black; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px">IMPORTING LIBRARIES🧾</div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %% [markdown]
# <a id="3"></a>
# ## <div style="text-align: left; background-color: #CD8C95 ; font-family: Trebuchet MS; color: black; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px">LOADING DATA📀</div>

# %%
#Importing the dataset
data = pd.read_csv('../input/car-price-data/cardata.csv')
# look the dataset
data.head()

# %% [markdown]
# ## The columns
# #### Car_name : Name of the cars
# #### Year : Year of the car when it was bought
# #### Selling_Price : Price at which car is being sold
# #### Kms_Driven : Number of kilometers the car is driven
# #### Fuel_Type : Fuel type of car (petrol / diesel / CNG)
# #### Seller_Type : Tells a Seller is Individual or a Dealer
# #### Transmission : Gear transmission of the car (Automatic / Manual)
# #### Owner : Number of previous owners of the car
# #

# %% [markdown]
# <a id="4"></a>
# ## <div style="text-align: left; background-color: #CD8C95 ; font-family: Trebuchet MS; color: black; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px">DATA EXPLORATORY & CLEANING</div>

# %%
# looking describe dataset
data.describe()

# %%
# looking the shape DataSet

print("The Shape DataSet = {} ".format(data.shape))

# %%
#Checking the dtypes of all the columns

data.info()

# %%
#checking duplicated value 

data.duplicated().sum()

# %%
# Describe price value

data["Present_Price"].describe().round(2)

# %% [markdown]
# - Avg price = 7.63
# - Min price = 0.32
# - Max price = 92.60

# %%
# finding the name of most expensive brand of car in Present_Price 
df1 = pd.DataFrame(data)
df1.loc[86, : ]

# %% [markdown]
# ## Most expensive car name = land cruiser

# %%
#  adding age column, until 2020
Age = 2020-df1.Year
df1.insert(2,"Age",Age)
df1.head()

# %%
# drop name_car and Year columns
df = pd.DataFrame(df1,columns = ['Age','Present_Price','Kms_Driven','Fuel_Type','Seller_Type','Transmission','Owner','Selling_Price'])
df

# %%
# change string columns  to number
T = {'Manual':1,'Automatic':0}
df.Transmission = [T[item] for item in df.Transmission]
S = {'Dealer':1 , 'Individual':0}
df.Seller_Type = [S[item] for item in df.Seller_Type]
F = {'Petrol':1, 'Diesel':2, 'CNG':3}
df.Fuel_Type = [F[item] for item in df.Fuel_Type]
df.head()

# %% [markdown]
# #
# ## noise detection plots

# %%
#plot Age & Selling_Price to find noise
plt.figure(figsize=(15,8))
plt.scatter(df['Age'],df['Selling_Price'])
plt.title('Age vs Selling_Price',fontsize=30,c='red')
plt.xlabel("Age",fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel("Selling_Price",fontsize=15)
plt.grid()
plt.show()

# %%
high = df['Age'].nlargest(3)
high

# %%
df.loc[37, : ]

# %%
df.loc[39, : ]

# %%
df.loc[77, : ]

# %%
high= df['Selling_Price'].nlargest(1)
high

# %%
#plot Present_Price & Selling_Price to find noise
plt.figure(figsize=(15,8))
plt.scatter(df['Present_Price'],df['Selling_Price'])
plt.title('Present_Price vs Selling_Price',fontsize=30,c='red')
plt.xlabel("Present_Price",fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel("Selling_Price",fontsize=15)
plt.grid()
plt.show()

# %%
high= df['Present_Price'].nlargest(1)
high

# %%
df.loc[86, : ]

# %%
print(df.loc[[86]])

# %% [markdown]
# ## I found out that  the row of index 86, isn't noise.this is the most expensive car and reliable
# #

# %%
#plot Kms_Driven & Selling_Price to find noise
plt.figure(figsize=(15,8))
plt.scatter(df['Kms_Driven'],df['Selling_Price'])
plt.title('Kms_Driven vs Selling_Price',fontsize=30,c='red')
plt.xlabel("Kms_Driven",fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel("Selling_Price",fontsize=15)
plt.grid()
plt.show()

# %%
high= df['Kms_Driven'].nlargest(1)
high

# %%
df.loc[196, : ]

# %% [markdown]
# #### this is true that a car has worked 500000 kilometer in 12 years
# #

# %%
#plot Owner & Present_Price to find noise
plt.figure(figsize=(15,8))
plt.scatter(df['Owner'],df['Present_Price'])
plt.title('Owner vs Present_Price',fontsize=30,c='red')
plt.xlabel("Owner",fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel("Present_Price",fontsize=15)
plt.grid()
plt.show()

# %%
#Checking if there is a car that had a previous owner but the price is zero?
df100= df[df['Owner']==1]
df100

# %% [markdown]
# ## there is not exist a car that had a previous owner but the price is zero.

# %%
#plot Fuel_Type & Selling_Price to find noise
plt.figure(figsize=(15,8))
plt.scatter(df['Fuel_Type'],df['Selling_Price'])
plt.title('Fuel_Type vs Selling_Price',fontsize=30,c='red')
plt.xlabel("Fuel_Type",fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel("Selling_Price",fontsize=15)
plt.grid()
plt.show()

# %%
#plot Seller_Type & Selling_Price to find noise
plt.figure(figsize=(15,8))
plt.scatter(df['Seller_Type'],df['Selling_Price'])
plt.title('Seller_Type vs Selling_Price',fontsize=30,c='red')
plt.xlabel("Seller_Type",fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel("Selling_Price",fontsize=15)
plt.grid()
plt.show()

# %%
#plot Transmission & Selling_Price to find noise
plt.figure(figsize=(15,8))
plt.scatter(df['Transmission'],df['Selling_Price'])
plt.title('Transmission vs Selling_Price',fontsize=30,c='red')
plt.xlabel("Transmission",fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel("Selling_Price",fontsize=15)
plt.grid()
plt.show()

# %%
#plot Owner & Selling_Price to find noise
plt.figure(figsize=(15,8))
plt.scatter(df['Owner'],df['Selling_Price'])
plt.title('Owner vs Selling_Price',fontsize=30,c='red')
plt.xlabel("Owner",fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel("Selling_Price",fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# ###  I found out that, there isn't any noise because all far points are rational
# ### but for testing , in another code , I made a model by deleting far points,the results was poor
# ### so I choose the model with all data, that has better score and I don't delet any point

# %% [markdown]
# #
# #
#
# ###  checking missing values

# %%
#view missing values
import missingno as msno
msno.matrix(df)
plt.show()

# %% [markdown]
# ## there is no missing values
#
# #
# #

# %% [markdown]
# <a id="5"></a>
# ## <div style="text-align: left; background-color: #CD8C95 ; font-family: Trebuchet MS; color: black; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px">DATA VISUALIZATION AND ANALISYS📊</div>

# %%
# Which most car name repeats in the Dataset
plt.figure(figsize = [30, 10])
sns.countplot(data["fCar_Name"],order = data["fCar_Name"].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %%
# Average price depends on the fuel type

FP = data.groupby("Fuel_Type")["Present_Price"].mean()
FP

# %%
# the average price depends on the car name

DP = data.groupby("fCar_Name")["Present_Price"].mean()
DP

# %%
# counting catagorical columns
colom= ['Age','Fuel_Type','Seller_Type','Transmission','Owner']
i=1
plt.figure(figsize= (20,40))
for col in colom:
    plt.subplot(9,2,i)
    #sns.distplot(df[col])#This function combines the matplotlib hist function with the seaborn kdeplot()
    sns.countplot(data[col])#This function is intended to complement other plots by showing the location of individual observations
    i=i+1
plt.show()

# %%
data.hist(bins=50, figsize=(20, 10),xlabelsize= 10 )
plt.show()

# %% [markdown]
# <a id="6"></a>
# ## <div style="text-align: left; background-color: #CD8C95 ; font-family: Trebuchet MS; color: black; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px">MAKING LINEAR REGRESSION MODEL</div>

# %%
#feature_cols = ['Present_Price','Seller_Type','Fuel_Type','Transmission','Age','Owner','Kms_Driven']
x = pd.DataFrame(df , columns=['Present_Price','Seller_Type','Fuel_Type','Transmission','Age','Owner','Kms_Driven'])
y = df.Selling_Price.values.reshape(-1,1) # Target variable

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2 ,random_state = 0)
regressor = LinearRegression()
regressor.fit(x_train , y_train)
y_pred = regressor.predict(x_test)
r2 = metrics.r2_score(y_test , y_pred)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test , y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test , y_pred))
print('Root Mean Squared Error:',np.sqrt(metrics.mean_squared_error(y_test , y_pred)))
print('R2 score:',r2)

# %% [markdown]
# ###  R2 score: 0.9134181721223894

# %% [markdown]
# <a id="7"></a>
# ## <div style="text-align: left; background-color: #CD8C95 ; font-family: Trebuchet MS; color: black; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px">MAKING NONLINEAR MODEL TO ACHIVE BETTER SCORE</div>

# %%
# correlation to find a ranking for importance of features for give more dimention
sns.clustermap(df.corr(), cmap = "vlag", dendrogram_ratio = (0.1, 0.2),annot = True, linewidths = .8, figsize = (9,10))
plt.show()

# %% [markdown]
# ## feature importance
# #### 1- Present_Price
# #### 2- Seller_Type
# #### 3- Fuel_Type
# #### 4- Transmission
# #### 5- Age
# #### 6- Owner
# #### 7- Kms_Driven
# #
# #

# %% [markdown]
# ### adding power 2 of columns if they improve the score

# %%
# making a dataframe without target to make function
x1 = pd.DataFrame(df , columns=['Present_Price','Seller_Type','Fuel_Type','Transmission','Age','Owner','Kms_Driven'])

# making function
def check(pow,testsize):
    r2 = 0.9134181721223894
    for column in x1:
        j = column+ str(pow)
        n = x1[column]**pow
        x.insert(0, j, n)
        x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=testsize ,random_state = 0)
        regressor = LinearRegression()
        regressor.fit(x_train , y_train)
        y_pred = regressor.predict(x_test)
        r2_new = metrics.r2_score(y_test , y_pred)
        if r2_new < r2:
            x.drop([j],axis =1,inplace = True)
        else:
            r2 = r2_new
    print('R2 score:',r2)

# %%
check(2,0.2)

# %% [markdown]
# ### R2 score: 0.9311515333475077
# #### after add power 2 of columns if they improve the score
# #

# %% [markdown]
# ### adding power 3 of columns if they improve the score

# %%
# making a function to add power3 of columns if they improve the score
def check(pow,testsize):
    r2 = 0.9311515333475077
    for column in x1:
        j = column+ str(pow)
        n = x1[column]**pow
        x.insert(0, j, n)
        x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=testsize ,random_state = 0)
        regressor = LinearRegression()
        regressor.fit(x_train , y_train)
        y_pred = regressor.predict(x_test)
        r2_new = metrics.r2_score(y_test , y_pred)
        if r2_new < r2:
            x.drop([j],axis =1,inplace = True)
        else:
            r2 = r2_new
    print('R2 score:',r2)

# %%
check(3,0.2)

# %% [markdown]
# ### R2 score: 0.931151537309435
# #### after add power 3 of columns if they improve the score
# #

# %% [markdown]
# ### adding power 4 of columns if they improve the score

# %%
# adding power 4 of columns if they improve the score
def check(pow,testsize):
    r2 = 0.931151537309435
    for column in x1:
        j = column+ str(pow)
        n = x1[column]**pow
        x.insert(0, j, n)
        x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=testsize ,random_state = 0)
        regressor = LinearRegression()
        regressor.fit(x_train , y_train)
        y_pred = regressor.predict(x_test)
        r2_new = metrics.r2_score(y_test , y_pred)
        if r2_new < r2:
            x.drop([j],axis =1,inplace = True)
        else:
            r2 = r2_new
    print('R2 score:',r2)

# %%
check(4,0.2)

# %% [markdown]
# ### R2 score: 0.931151537309435
# #### after add power 3 of columns if they improve the score
# #
# #

# %% [markdown]
# ### power 5 doesn't change R2 score so I don't continue raising power
# #
# #
# #

# %% [markdown]
# ### making normal distribution of Age column
# ### because the shape of points for plot of Age Selling_Price is like normal distribution

# %%
# we use standard deviation and mean to make normal distribution
df.describe()

# %%
#add normal distribution of column Age
import math
normal_Age = (1/ (2.891554*((2*math.pi)**(1/2))))* (math.e ** ((-(x1.Age - 6.372093)**2))/(2*2.891554**2))
x.insert(0,'normal_Age',normal_Age)
x

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2 ,random_state = 0)
regressor = LinearRegression()
regressor.fit(x_train , y_train)
y_pred = regressor.predict(x_test)
r2 = metrics.r2_score(y_test , y_pred)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test , y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test , y_pred))
print('Root Mean Squared Error:',np.sqrt(metrics.mean_squared_error(y_test , y_pred)))
print('R2 score:',r2)

# %% [markdown]
# ### R2 score: 0.9321753970347164
# #### after adding normal distribution of column Age

# %% [markdown]
# #
# #
# ### add pruduct of features

# %%
# making a function for product of columns if they improve the score
def product(testsize):
    i=1
    r2 = 0.9321753908823595
    for column in x1:
        if i == 7:
            break
        if i==6:
            x2 = x1[['Kms_Driven']]
        if i < 6:
            x2 = x1.iloc[ : ,i :]
        for col in x2:
            j = column+col
            n = x1[column] * x2[col]
            x.insert(0, j, n)
            x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=testsize ,random_state = 0)
            regressor = LinearRegression()
            regressor.fit(x_train , y_train)
            y_pred = regressor.predict(x_test)
            r2_new = metrics.r2_score(y_test , y_pred)
            if r2_new < r2:
                x.drop([j],axis =1,inplace = True)
            if r2_new >= r2:
                r2 = r2_new
        i+=1
        
    print('R2 score:',r2)

# %%
product(0.2)

# %% [markdown]
# ### R2 score: 0.970902566404461
# #### this is the score after using useful product of features
# #

# %% [markdown]
# <a id="8"></a>
# ## <div style="text-align: left; background-color: #CD8C95 ; font-family: Trebuchet MS; color: black; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px">CROSS VALIDATION</div>
#
# #### I use cross validation method for nonlinear regression
# #### because the score of K-Fold for linear regression was much smaller than nonlinear

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=4)
results = (cross_val_score(regressor, x, y, cv=k_fold, n_jobs=1))
print(results)
print(np.mean(results))

# %% [markdown]
# #### 4 fold has the best score, so I delet the second fold
# #

# %%
df2 = pd.DataFrame(df.Selling_Price)
frames = [df2,x]
df3 = pd.concat(frames,axis=1)
# deleting the third fold
df4 = df3[df3.index < 75]
df5 = df3[df3.index > 150]
df6 = df4.append(df5)
df6.reset_index(drop = True , inplace = True)
df6

# %% [markdown]
# ####  rows from 75 to 150 were deleted
# #

# %%
y = df6.Selling_Price.values.reshape(-1,1)
x = df6.drop(['Selling_Price'], axis = 1)
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)
regressor = LinearRegression()
regressor.fit(x_train , y_train)
y_pred = regressor.predict(x_test)
r2 = metrics.r2_score(y_test , y_pred)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test , y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test , y_pred))
print('Root Mean Squared Error:',np.sqrt(metrics.mean_squared_error(y_test , y_pred)))
print('R2 score:',r2)

# %% [markdown]
# ### R2 score: 0.9731507333562434
# #### this is  final score after using cross validation
# #

# %% [markdown]
# ### intercept and coeficients

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2 ,random_state = 0)
regressor = LinearRegression()
regressor.fit(x_train , y_train)
y_pred = regressor.predict(x_test)
print('intercept =',regressor.intercept_)
m = regressor.coef_
cdf = pd.DataFrame(m.transpose(), x.columns, columns = ['coeficients'])
print(cdf)

# %% [markdown]
# <a id="9"></a>
# ## <div style="text-align: left; background-color: #CD8C95 ; font-family: Trebuchet MS; color: black; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px">SHOW PREDICTIONS</div>

# %%
# compare y_test,y_pred
plt.scatter(y_test,y_pred)
plt.grid()
plt.xlabel("Test")
plt.ylabel("Prediction")

# %% [markdown]
# ### angle 45 degree shows that the prediction is good
# #

# %%
compare = pd.DataFrame({'Actual': y_test.flatten(),'Predicted':y_pred.flatten()})
compare

# %%
a = x_test.Present_Price
b = y_test
c = x_test.Present_Price
d = y_pred
plt.figure(figsize=(15,8))
plt.xlabel("Present_Price",fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel("Selling_Price",fontsize=15)
plt.yticks(fontsize=15)
plt.scatter(a,b,label ='test')
plt.scatter(c,d,label ='pred')
plt.legend(loc='lower right')
plt.grid()
plt.show()

# %%
x_test.insert(0,"y_test",y_test)
x_test.insert(0,"y_pred",y_pred)
df10 = x_test.sort_values(by =["Present_Price"])

# %%
a = df10.Present_Price
b = df10.y_test
c = df10.Present_Price
d = df10.y_pred
plt.figure(figsize=(15,8))
plt.xlabel("Present_Price",fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel("Selling_Price",fontsize=15)
plt.yticks(fontsize=15)
plt.scatter(a,b,label ='test')
plt.plot(c,d,label ='pred')
plt.legend(loc='lower right')
plt.grid()
plt.show()

# %%
a = x_test.Seller_Type
b = y_test
c = x_test.Seller_Type
d = y_pred
plt.figure(figsize=(15,8))
plt.xlabel("Seller_Type",fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel("Selling_Price",fontsize=15)
plt.yticks(fontsize=15)
plt.scatter(a,b,label ='test')
plt.scatter(c,d,label ='pred')
plt.legend(prop={'size':10},bbox_to_anchor=(1.13,1))
plt.grid()
plt.show()

# %%
a = x_test.Age
b = y_test
c = x_test.Age
d = y_pred
plt.figure(figsize=(15,8))
plt.xlabel("Age",fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel("Selling_Price",fontsize=15)
plt.yticks(fontsize=15)
plt.scatter(a,b,label ='test')
plt.scatter(c,d,label ='pred')
plt.legend(prop={'size':10},bbox_to_anchor=(1.13,1))
plt.grid()
plt.show()

# %%
df10 = x_test.sort_values(by =["Age"])
a = df10.Age
b = df10.y_test
c = df10.Age
d = df10.y_pred
plt.figure(figsize=(15,8))
plt.xlabel("Age",fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel("Selling_Price",fontsize=15)
plt.yticks(fontsize=15)
plt.scatter(a,b,label ='test')
plt.plot(c,d,label ='pred')
plt.legend(loc='upper right')
plt.grid()
plt.show()

# %%
a = x_test.Kms_Driven
b = y_test
c = x_test.Kms_Driven
d = y_pred
plt.figure(figsize=(15,8))
plt.xlabel("Kms_Driven",fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel("Selling_Price",fontsize=15)
plt.yticks(fontsize=15)
plt.scatter(a,b,label ='test')
plt.scatter(c,d,label ='pred')
plt.legend(prop={'size':10},bbox_to_anchor=(1.13,1))
plt.grid()
plt.show()

# %%
df10 = x_test.sort_values(by =["Kms_Driven"])
a = df10.Kms_Driven
b = df10.y_test
c = df10.Kms_Driven
d = df10.y_pred
plt.figure(figsize=(15,8))
plt.xlabel("Kms_Driven",fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel("Selling_Price",fontsize=15)
plt.yticks(fontsize=15)
plt.scatter(a,b,label ='test')
plt.plot(c,d,label ='pred')
plt.legend(loc='upper right')
plt.grid()
plt.show()

# %% [markdown]
# #
# ### now we want to predict the cost of this car
# #### Present_Price = 11.23
# #### Kms_Driven = 42000
# #### Fuel_Type = Petrol(1)
# #### Seller_Type = Dealer(1)
# #### Transmission = Manual(1)
# #### Owner = 0
# #### Age = 10
# #### Selling_Price =?

# %%
for x in df6:
    print(x)

# %%
df22 = pd.DataFrame({"Selling_Price":[30],
                    "AgeKms_Driven":[420000],
                    "AgeOwner":[0],
                    "Fuel_TypeKms_Driven":[42000],
                    "Fuel_TypeOwner":[0],
                    "Fuel_TypeTransmission":[1],
                    "Seller_TypeKms_Driven":[42000],
                    "Seller_TypeAge":[10],
                    "Seller_TypeTransmission":[1],
                    "Present_PriceAge":[112.3],
                    "Present_PriceTransmission":[11.23],
                    "normal_Age":[1.586457602763525e-08],
                    "Seller_Type4":[1],
                    "Owner3":[0],
                    "Kms_Driven2":[1764000000],
                    "Owner2":[0],
                    "Fuel_Type2":[1],
                    "Seller_Type2":[1],
                    "Present_Price2":[126.1129],
                    "Present_Price":[11.23],
                    "Seller_Type":[1],
                    "Fuel_Type":[1],
                    "Transmission":[1],
                    "Age":[10],
                    "Owner":[0],
                    "Kms_Driven":[42000]})

# %%
df6

# %%
df22

# %%
df_final = df6.append(df22)
df_final

# %%
train = df_final.iloc[ :225]
test =  df_final.iloc[225: ]

# %%
x_train = df_final[['AgeKms_Driven','AgeOwner','Fuel_TypeKms_Driven',
                    'Fuel_TypeOwner','Fuel_TypeTransmission','Seller_TypeKms_Driven',
                    'Seller_TypeAge','Seller_TypeTransmission','Present_PriceAge',
                    'Present_PriceTransmission','normal_Age','Seller_Type4','Owner3',
                    'Kms_Driven2','Owner2','Fuel_Type2','Seller_Type2',
                    'Present_Price2','Present_Price','Seller_Type',
                    'Fuel_Type','Transmission','Age','Owner','Kms_Driven']][ :225]
y_train = df_final[['Selling_Price']][:225].values.reshape(-1,1)

# %%
x_test = df_final[['AgeKms_Driven','AgeOwner','Fuel_TypeKms_Driven',
                    'Fuel_TypeOwner','Fuel_TypeTransmission','Seller_TypeKms_Driven',
                    'Seller_TypeAge','Seller_TypeTransmission','Present_PriceAge',
                    'Present_PriceTransmission','normal_Age','Seller_Type4','Owner3',
                    'Kms_Driven2','Owner2','Fuel_Type2','Seller_Type2',
                    'Present_Price2','Present_Price','Seller_Type',
                    'Fuel_Type','Transmission','Age','Owner','Kms_Driven']][225: ]

# %%
regressor.fit(x_train,y_train)
y_pred = regressor.predict(x_test)

# %%
print(y_pred)

# %% [markdown]
# ## The pedicted price is: [[4.04975509]]
# ## The final R2 score is: 0.9731686566421694
# #

# %% [markdown]
# <img src="https://media.tenor.com/UYKubj1fwrsAAAAC/%E0%B8%88%E0%B8%9A-the-end.gif" length=20000 width=300>
