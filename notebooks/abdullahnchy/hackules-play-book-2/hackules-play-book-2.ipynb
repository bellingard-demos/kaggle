# %%
import pandas as pd

# %%
df = pd.DataFrame([
    {'name': 'mina', 'age': 13, 'gender': 'female', 'weight': 40, 'height': 1.2, 'human': True },
    {'name': 'raju', 'age': 11, 'gender': 'male', 'weight': 38, 'height': 1.1, 'human': True  },
    {'name': 'mithu', 'age': 5, 'gender': 'male', 'weight': 1, 'height': 0.2, 'human': False },
    {'name': 'dipu', 'age': 15, 'gender': 'male', 'weight': 55, 'height': 1.2, 'human': True },
    {'name': 'dadi', 'age': 75, 'gender': 'female', 'weight': 70, 'height': 1.5, 'human': True },
    {'name': 'ma', 'age': 30, 'gender': 'female', 'weight': 58, 'height': 1.6, 'human': True },
    {'name': 'baba', 'age': 35, 'gender': 'male', 'weight': 72, 'height': 1.8, 'human': True },
    {'name': 'apa', 'age': 37, 'gender': 'female', 'weight': 47, 'height': 1.6, 'human': True },
    {'name': 'lali', 'age': 12, 'gender': 'female', 'weight': 120, 'height': 1.9, 'human': False },
    {'name': 'lali', 'age': 12, 'gender': 'female', 'weight': 120, 'height': 1.9, 'human': False },
    {'name': 'lali', 'age': 11, 'gender': 'female', 'weight': 120, 'height': 1.9, 'human': False }
])

# %%
df

# %%
type(df['age'])

# %%
len(dir(df['age']))

# %%
df['age'].value_counts(ascending=False, normalize=True)

# %%
filter1 = df['age'] > 12

# %%
filter2 = df['weight'] > 40

# %%
filter = filter1 & filter2

# %%
df[filter]

# %%
f = df['gender'].isin(['male', 'female'])

# %%
df[f]

# %%
df

# %%
df.drop_duplicates(subset=['name', 'age'], inplace=True)

# %%
df.sort_values('age',inplace=True)

# %%
df

# %%
a = df.duplicated(subset=['name','age'])

# %%
df[a]
