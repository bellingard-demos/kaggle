# %%
a=4
print(a)
type(a)

# %%
b=1.564747
print(b)
type(b)

# %%
c="ABCD1234"
print(c)
type(c)

# %% [markdown]
# **Variable with number**

# %% [markdown]
# **integer,floating point,complex numbers**

# %%
a = 2 + 3j
print(a)
type(a)

# %% [markdown]
# **working with multiple variables**

# %%
Gross_profit=10

# %%
Revenue=100

# %%
Gross_profit_margin=(Gross_profit/Revenue)*100
print(Gross_profit_margin)
type(Gross_profit_margin)

# %%
Revenue=100
RevA=8

# %%
Revenue=Revenue+RevA
print(Revenue)

# %%
a=142567282992762654262
print(a)

# %%
first_name="akash"
last_name="gare"

# %%
name=first_name+" "+last_name
print(name)

# %% [markdown]
# **Variables with boolean** - True/False

# %%
a=3
b=5
c=a>b
print(c)
type(c)

# %%
c=True
type(c)

# %% [markdown]
# **Multiple assignments**

# %%
a,b,c="akash","gare",26
print(b)

# %% [markdown]
# **Naming convention of variables**
# * Should not contain any space
# * Should not contain any special character except underscore eg;akash_gare
# * Variables are case sensitive
# * "#" is used as comment*

# %% [markdown]
# **Reserved keywords**
#
# and       del       from      not       while
# as        elif      global    or        with
# assert    else      if        pass      yield
# break     except    import    print
# class     exec      in        raise
# continue  finally   is        return
# def       for       lambda    try

# %% [markdown]
# **Print Statement**

# %%
a=5
print(a)

# %%
b=5*6*5/5
print(b)

# %%
print("The value of a and b are", a,",",b, "based on inputs")

# %% [markdown]
# **Swaping 2 variables**

# %%
a=2
b=4

# %%
c=a
a=b
b=c

# %%
print(a,b) #swapping two variables
