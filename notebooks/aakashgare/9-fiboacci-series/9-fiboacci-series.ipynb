# %%
a=1
b=2

c=a #c=1
a=b #a=2
b=c #b=1
print(a)
print(b)

# %% [markdown]
# Fibonacci series
# i    a        b    c
# 1    0(1)     1    1
# 2    1(1)     2    1
# 3    1(2)     3    2
# 4    2(3)     5    3

# %%
a=0
b=1
for i in range(1,21):
    print(a, end=" ")   #end="" is used to get the output in same line and "\n"
    c=b
    b=b+a
    a=c
