# %% [markdown]
# **NUMPY** is  a library that :
#
# * provides us an optimized way to store data
# * Easier to handle the data
# * It is fast and takes less memory
# * It is easier to learn numpy
# * Memory management can be done as it is more closer to hardware
# * A lot of mathematical operations can be performed on data stored in numpy array

# %%
import numpy as np

# %% [markdown]
# **1D array**

# %%
a = np.array([2,3,4,6])
a

# %% [markdown]
# **Implicit Coversion**

# %%
b = np.array([1,2,3,4.5])
b

# %% [markdown]
# Using arange method

# %%
c=np.arange(11)
c

# %%
c=np.arange(10,20,2)
c

# %% [markdown]
# Memory management

# %% [markdown]
# ![image.png](attachment:b5f93813-92c0-49d8-b964-cfea166cd83c.png)

# %%
d=np.array([2,3,300,5], dtype = np.int16)
d

# %%
help(np.array)

# %% [markdown]
# Using linspace method

# %%
e=np.linspace(1,10,20) #linspace (first, last(inclusive), count of number)
e

# %% [markdown]
# Attributes-shapes and dimensions

# %%
a

# %%
a.ndim  #ndim is attribute not method, attributes are used for read only method

# %%
a.shape

# %% [markdown]
# **2-D Array**

# %%
a = np.array([[2.4,3,4,5],
             [6,7,8,9],
            [3,2,5,7]])

# %%
a

# %% [markdown]
# Attributes

# %%
a.ndim #it will give the information about the number of dimension

# %%
a.shape

# %% [markdown]
# **2-D array using methods**

# %% [markdown]
# Using on method

# %%
a=np.ones([3,6])
a

# %% [markdown]
# using zeros method

# %%
b=np.zeros([3,6])
b

# %% [markdown]
# using eye method

# %%
c = np.eye(4,4)  # is also known as identity matrix
c

# %% [markdown]
# using diagonal method

# %%
d=np.diag([1,3,5,6,7])
d

# %% [markdown]
# Extracting diagonals

# %%
np.diag(d)

# %% [markdown]
# **3-D array**
# ![image.png](attachment:5e0e6e94-fe86-4acb-a4c1-702ed5be6022.png)

# %%
a=np.array([[[311,312,313],[321,322,323],[331,332,333]],
          [[211,212,213],[221,222,223],[231,232,233]],
           [[111,112,113],[121,122,123],[231,232,233]]])
a

# %%
a.ndim

# %%
a.shape

# %% [markdown]
# Addition of numbers without numpy array

# %%
import numpy as np

# %%
import time

# %%
initial_time=time.time()
a=0
for i in range(10000000):
    a=a+i
print(a)
final_time=time.time()
difference1=final_time-initial_time
print(difference1)

# %% [markdown]
# using numpy array

# %%
initial_time=time.time()
a=np.arange(10000000)
print(np.sum(a))
final_time=time.time()
difference2=final_time-initial_time
print(difference2)

# %%
difference1/difference2
