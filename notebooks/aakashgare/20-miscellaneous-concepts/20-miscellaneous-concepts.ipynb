# %%
a="we are learning {}"
b=a.format("Analytics")
b

# %%
s="{1} is a {0} Company in {2}"
p=s.format("tech","Google","USA")
p

# %%
s = "{Company_name} is a {Company_type} company"
p=s.format(Company_type="tech",Company_name="Google")
p

# %%
d = {
    "Apple" : 2368689,
    "Google" : 8893845,
    "Facebook" : 76849309,
    "Netflix" : 5654728
}
for i in d :
    print("{:<10}-{:,}".format(i,d[i]))

# %%
a = "the profit generated by Apple is {:,}"
b=a.format(12457)
b
