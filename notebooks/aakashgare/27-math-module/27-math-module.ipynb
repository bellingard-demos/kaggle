# %% [markdown]
# https://www.w3schools.com/python/module_math.asp

# %%
import math

# %%
math.e

# %%
math.pi

# %%
round(math.pi,2)

# %% [markdown]
# **Round off decimals**

# %%
a=-6.5

# %%
math.ceil(a)  # this will round off to the next high integer

# %%
math.floor(a)  # this will round off to the next high integer

# %%
a=4.5
math.ceil(a)

# %%
math.floor(a)

# %% [markdown]
# **Truncate**

# %%
b=3.245
math.trunc(b)

# %% [markdown]
# **Exponential and logarithmic functions**

# %%
x=3
math.exp(x)      # e to the power of  3

# %%
math.log(1000) # by default the base is e

# %%
math.log(1000,10) #here the base is 10

# %% [markdown]
# **Trignometric function**

# %%
math.sin(math.pi/2)

# %%
degree=int(input("Enter the degree"))
math.sin(math.radians(degree))

# %%
degree=int(input("Enter the degree"))
math.cos(math.radians(degree))

# %%
degree=int(input("Enter the degree"))
math.tan(math.radians(degree))

# %% [markdown]
# **Mathematical functions**

# %%
math.sqrt(4)

# %%
math.factorial(4)

# %%
l= [1,1.2,13,1.4,5.5,6.6,7]
math.fsum(l)
