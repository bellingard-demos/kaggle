# %% [markdown]
# open the file

# %%
f=open("/kaggle/input/poetry/Kanye_West.txt")

# %% [markdown]
# **Reading the file**

# %%
f.read()

# %% [markdown]
# **Read file using print function**

# %%
f.close()

# %%
f=open("/kaggle/input/poetry/Kanye_West.txt")

# %%
print(f.read())

# %% [markdown]
# **print using loop**

# %%
f.close()

# %%
f=open("/kaggle/input/poetry/Kanye_West.txt")

# %%
for i in f:
    print(i)

# %% [markdown]
# **Read line by line**

# %%
f.readline()

# %% [markdown]
# **Other important methods**

# %%
f=open("/kaggle/input/poetry/Kanye_West.txt")

# %%
f.read(3)

# %%
help(open)

# %%
f.close()

# %%
f=open("/kaggle/input/poetry/Kanye_West.txt", encoding='utf-8-sig')

# %%
f.read(3)

# %%
f.seek(0)

# %%
f.read(10)

# %%
f.close()

# %% [markdown]
# *     'r'       open for reading (default)
# *     'w'       open for writing, truncating the file first
# *     'x'       create a new file and open it for writing
# *     'a'       open for writing, appending to the end of the file if it exists
# *     'b'       binary mode
# *     't'       text mode (default)
# *     '+'       open a disk file for updating (reading and writing)
# *     'U'       universal newline mode (deprecated)**

# %% [markdown]
# **Write to the file**

# %%
f= open("test.txt", mode='w')

# %%
f.write("This is my second line")

# %%
f.close()

# %%
f= open("test.txt", mode='r')
print(f.read())   # here it will show only second line because it overrides the existing content

# %% [markdown]
# **Append to the file**

# %%
f= open("test.txt", mode='a')

# %%
f.write("Going good")

# %%
f.close()

# %%
f=open("test.txt", mode='r')
print(f.read(),end="\n")

# %% [markdown]
# **Binary files**-Non-text file images are stored as binary files the mode in the open function should be 'rb' (read binary)

# %%
img=open('/kaggle/input/cifar10-pngs-in-folders/cifar10/test/airplane/0001.png','rb')

# %%
store=img.read()  # store the content of imhg to variabe store

# %%
img.close()

# %%
img.readline()

# %%
a=open('plane.png', mode='wb')

# %%
a.write(store)

# %%
a.close()

# %%
img.close()

# %% [markdown]
# **Exceptional handling** It is important to close our file to make sure that the resources get free up .Also, there might be data loss in case we dont close the file

# %%
rm airplane.png

# %%
rm test.text

# %%
try: 
    f=open("/kaggle/input/poetry/al-green.txt")
    1/0
    f.close()  #this will not get executed
except:
    print("There is an issue in the try block")
finally:
    f.close()

# %%
f.read()

# %%
with open("Python.txt",'w') as f:  # is the file handler or variable
    f.write("I am learning python")  #once we get of this block, the file is automatically clsoe

# %%
x=open("Python.txt",'w')
x.write("I am learning python")
x.close()
