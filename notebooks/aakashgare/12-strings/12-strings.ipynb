# %% [markdown]
# String is sequence of characters or arrays of characters

# %%
a="Data Analytic's"
print(a)

# %%
a

# %% [markdown]
# **String indexing**

# %%
a[0]

# %%
len(a) #find the length of the string

# %%
a[-1]

# %% [markdown]
# **String slicing**
# *a[start:end:step]*

# %%
a[0:4]

# %%
a[0:15:2]

# %% [markdown]
# **substring**

# %%
add = "hyderabad 545678 gachibowli near wipro circle"

# %%
add.find("gachibowli") #it will return the index of the substring

# %% [markdown]
# **splitting**

# %%
z = "we are doing a good progress"

# %%
s=z.split()

# %%
z[1]

# %%
s[1]

# %%
y = "we-are-doing-a-good-progress"

# %%
t = y.split("-")

# %%
t[0]

# %% [markdown]
# **Stripping a string**: used to remove a leading and trailing spaces

# %%
d="Statistics"
e="Statistics  "

# %%
d==e

# %%
len(d)
len(e)

# %%
e=e.strip()

# %%
e #strips are immutable

# %%
name="  AKASH"
name = name.lstrip()  #in case to strip the beginning
name

# %%
w = "  i am learning python  "

# %%
w = w.strip()
w

# %% [markdown]
# **inbuilt function in string**

# %%
alphanumeric="abcfdgdh1233"
alphanumeric.isalnum()

# %%
password = "abdgh@234"
password.isalnum()

# %%
name="kapil sharma"
name.islower()

# %%
name="KAPIL SHARMA"
name.isupper()

# %%
city="Banglore"
city=city.upper()

# %%
city

# %%
city="Banglore"
city=city.lower()
city

# %%
city="hyderabad"
city=city.capitalize()
city

# %%
name="Akash Gare"
name.swapcase()

# %%
name="akash gare"
name.title()

# %%
name.endswith("gare")

# %%
a = "I am learning powerbi"
b = a.split()
for i in b:
    print(i)

# %% [markdown]
# **Reversing string**

# %%
len(a)

# %%
"akash"+"gare"

# %%
l=len(a)
r=" "
while l>0:
    r = r + a[l-1]
    print(r)
    l=l-1
print(r)
