# %% [markdown]
# # Importing Dataset
# For the analysis of students performance in exams, we have to import a dataset in csv file

# %% [markdown]
# #  Student academic performance
# In this notebook we are going to analyze the performance of students academic performance, for this the first step is to import - numpy, pandas, and matplotlib libraires

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a=pd.read_csv('/kaggle/input/xAPI-Edu-Data/xAPI-Edu-Data.csv')
##With the help of Pandas library, we can import and read the csv file in our kaggle platform

# %%
a #Here is the entire dataset of students along with the necessary information as well as their scores in maths, reading, and writing

# %% [markdown]
# # Checking for null values
# * Let us first check if there is any null values in any of the columns where we have to perform the analysis
# * In case there will be any null values in the, we need to perform data cleaning
# * Thus, we have to either replace the null values or completely remove them from the dataset

# %%
a.info() #As we can see, there is no null values in any of the columns, so it doesn't require data cleaning

# %% [markdown]
# **Now let us jump into some more statistical values which are - Mean, St. Deviation, Min. value, Max. value, etc. of the marks scored by the students in math, reading, and writing departments.**

# %%
a.describe

# %%
a.head()

# %% [markdown]
# # Replacing space in the column names
# * In order to avoid any sort of errors while performing the analysis, it is must to replace the space between the column names
# * Here, we are replacing the space with the underscore (_)

# %%
a.columns=a.columns.str.replace(" ","_")
a

# %%
a.columns=a.columns.str.upper()
a
