# %% [markdown]
# **Addition**

# %%
Sales_A=20
Sales_B=66.6
Total_sales=Sales_A+Sales_B
print(Total_sales)

# %% [markdown]
# **Subtraction**

# %%
a=34
b=36
c=b-a
print(c)

# %% [markdown]
# **Multiplication**

# %%
fees=400
students=5
Total_fees=fees*students
print(Total_fees)

# %% [markdown]
# **Division**

# %%
yearly_sales=12000
averagesales_per_month=12000/12
print(averagesales_per_month)

# %% [markdown]
# **Modulus Division** - for finding the remainder

# %%
a=211
remainder=a%2
print(remainder)

if remainder == 1:
   print("odd")

# %% [markdown]
# **floor division** for finding the quotient

# %%
a=93
b=7
c=93//7
print(c)

# %% [markdown]
# **Exponentiation**

# %%
base = 2
power = 3
answer = base**power
print(answer)
