# %% [markdown]
# **Equal to**

# %%
a=2
b=3
a==b   #theis is a different between = and == ,here == is for true or false(boolean)

# %%
a=22
if a%2==1:
    print ("odd")
else:
    print("even")

# %% [markdown]
# **Not equal to**

# %%
a=5
b=7
a!=b

# %% [markdown]
# **Greater than**

# %%
Laptops=10
mouse=11
if Laptops>=mouse :
   print("mouse deficiency")
else :
  print("laptops deficency")

# %% [markdown]
# **Lesser than**

# %%
Laptops=12
mouse=11
if Laptops<=mouse :
   print("extra mouse")
else :
  print("extra laptop")
