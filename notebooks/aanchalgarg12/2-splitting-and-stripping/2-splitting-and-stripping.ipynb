# %%
add = "26/13, street no-14 vishwas nagar"

# %%
add.find("street")            #it will return the index of sub string.

# %% [markdown]
# **Splitting**

# %%
x = "This course is understandable"

# %%
 x.split()

# %%
y = "we-are-doing-progress"

# %%
y.split()

# %%
y.split("-")                 #to split the strings we have to add some arguments

# %% [markdown]
# **Stripping**

# %% [markdown]
# **stripping a string - used to remove the leading and trailing spaces**

# %%
d = "Finance"
e = " Finance "

# %%
d == e

# %%
len(d)

# %%
len(e)

# %%
e.strip()

# %%
e                           #strings are immutable

# %%
e = e.strip()

# %%
e

# %%
x = "  Aanchal  "
x.lstrip()

# %%
x = "  Aanchal  "
x.rstrip()

# %%
y = " My name is Aanchal Garg  "
y.strip()
