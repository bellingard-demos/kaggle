# %%
# %% [code] {"execution":{"iopub.status.busy":"2023-11-20T08:19:53.585644Z","iopub.execute_input":"2023-11-20T08:19:53.586157Z","iopub.status.idle":"2023-11-20T08:19:53.592359Z","shell.execute_reply.started":"2023-11-20T08:19:53.586121Z","shell.execute_reply":"2023-11-20T08:19:53.591308Z"}}
a=5
print(a)


# %% [code] {"execution":{"iopub.status.busy":"2023-11-20T08:20:41.004071Z","iopub.execute_input":"2023-11-20T08:20:41.004481Z","iopub.status.idle":"2023-11-20T08:20:41.012828Z","shell.execute_reply.started":"2023-11-20T08:20:41.004449Z","shell.execute_reply":"2023-11-20T08:20:41.011555Z"}}
b=4.6
type(b)

# %% [code] {"execution":{"iopub.status.busy":"2023-11-20T08:22:13.338878Z","iopub.execute_input":"2023-11-20T08:22:13.339899Z","iopub.status.idle":"2023-11-20T08:22:13.346479Z","shell.execute_reply.started":"2023-11-20T08:22:13.339860Z","shell.execute_reply":"2023-11-20T08:22:13.345386Z"}}
c="ABC234"
type(c)

# %% [markdown]
# 
# **variable with numbers**

# %% [code] {"execution":{"iopub.status.busy":"2023-11-21T08:06:55.733302Z","iopub.execute_input":"2023-11-21T08:06:55.733717Z","iopub.status.idle":"2023-11-21T08:06:55.743192Z","shell.execute_reply.started":"2023-11-21T08:06:55.733687Z","shell.execute_reply":"2023-11-21T08:06:55.741673Z"}}
a= 4+2j
print(a)
type(a)

# %% [code]


# %% [markdown]
# **working with multiple variables**

# %% [code]
Gross_profit = 15

# %% [code]
Revenue = 100

# %% [code] {"execution":{"iopub.status.busy":"2023-11-21T08:17:40.838246Z","iopub.execute_input":"2023-11-21T08:17:40.838775Z","iopub.status.idle":"2023-11-21T08:17:40.864266Z","shell.execute_reply.started":"2023-11-21T08:17:40.838738Z","shell.execute_reply":"2023-11-21T08:17:40.862898Z"}}
Gross_profit_margin =  ( Gross_profit / Revenue)*100
print (Gross_profit_margin)
type(Gross_profit_margin)

# %% [code]
Revenue = 100
RevA = 8

# %% [code] {"execution":{"iopub.status.busy":"2023-11-21T08:17:48.061412Z","iopub.execute_input":"2023-11-21T08:17:48.061878Z","iopub.status.idle":"2023-11-21T08:17:48.088232Z","shell.execute_reply.started":"2023-11-21T08:17:48.061840Z","shell.execute_reply":"2023-11-21T08:17:48.086445Z"}}
Revenue = Revenue + RevA
print(Revenue)

# %% [code]


# %% [code]


# %% [code]


# %% [code]


# %% [markdown]
#

# %%
Address = 26/13,vishwas nagar shahdara delhi-110032
print(Address)

# %%
First_name = "Ayush"
Last_name = "Jain"
name = First_name+" "+Last_name
print(name)

# %% [markdown]
# **Variable with Booleans**- True/False

# %%
a= 3
b= 4
c=a>b
print(c)
type(c)

# %%
a= "True"
print(a)
type(a)

# %% [markdown]
# **Multiple Assignments**

# %%
a,b,c= "Ayush jain",26,34.6
print(a)
