# %% [markdown]
# **Equal to**

# %%
a = 3
b = 2              #There is a difference between = and ==.
a == b

# %%
a = 22 
if a%2 == 1 :
    print("odd")
else:
        print("even")

# %% [markdown]
# **Not equal to**

# %%
x = 2
y = 3                        #! is used for not.
x != y

# %% [markdown]
# **Greater than**

# %%
Assets = 45
Liabilities = 60
if Liabilities > Assets :
    print("Asset Deficiency")

# %% [markdown]
# ****greater than and equal to****

# %%
Assets = 60
Liabilities = 60
if Assets >= Liabilities :
    print("right")

# %% [markdown]
# **Lesser than**

# %%
Assets = 30
Liabilities = 50
if Assets < Liabilities :
    print("true")

# %% [markdown]
# ****
