# %%
a = "xyz123"
a.isalnum()

# %%
a = "Aanchal"
a.isalpha()

# %%
a = "AANCHAL"
a.isupper()

# %%
a = "aanchal"
a.islower()

# %%
city = "Delhi"
city.upper()

# %%
city = "Delhi"
city = city.upper()
city

# %%
city = "DELhi"
city = city.lower()
city

# %%
country = "india"
country.capitalize()

# %%
country = "India"
country.swapcase()

# %%
name = "aanchal garg"
name.title()

# %%
name.endswith("garg")

# %%
country = "india"
country.title()

# %%
name.endswith("g")                #because garg ends with "g" thatswhy its showing true.
