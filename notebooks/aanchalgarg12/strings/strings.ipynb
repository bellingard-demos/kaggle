# %%
a = "Data Analytic's"
print(a)

# %% [markdown]
# **String Indexing**

# %%
a[1]

# %%
len(a)           #to find the length of the string

# %%
a[-2]                   #to access the second last element

# %%
a[-1]
a[14]

# %% [markdown]
# **string slicing**

# %%
a =  "Aanchal"

# %%
a[5]

# %%
a[0:4]

# %%
a[2:6]

# %% [markdown]
# **a[start,end,step]**

# %%
a[0:4:2]

# %%
a[0:6:3]       #answer should be "Acl" .

# %%
a = "Python"

a[0:6:3]
