# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('../input/imdb-video-games/imdb-videogames.csv')

# %%
data.head()

# %%
data.columns

# %%
data=data.drop(['Unnamed: 0', 'url'],axis=1)

# %%
data.head()

# %%
data.describe()

# %%
data.describe(include=['object','bool'])

# %%
data.info()

# %%
data.isnull().sum()

# %%
data.rating=data.rating.replace(np.nan,0)

# %%
data.votes=data.votes.replace(np.nan,0)

# %%
import seaborn as sns

# %%
data.columns

# %%
data[['name','certificate','votes','plot']].corr()

# %%
lst=data['plot'].tolist()
lst

# %%
data.votes

# %%
data.votes=data.votes.str.replace(',','')

# %%
data.votes=pd.to_numeric(data.votes)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(7,7))
sns.heatmap(data.corr(),annot=True)#n,c,v,p

# %% [markdown]
# Which game genres are the most popular?

# %%
pd.pivot_table(data=data,values='votes',index='Action',aggfunc='sum')

# %%
pd.pivot_table(data=data,values='votes',index='Adventure',aggfunc='sum')

# %%
pd.pivot_table(data=data,values='votes',index='Comedy',aggfunc='sum')

# %%
pd.pivot_table(data=data,values='votes',index='Crime',aggfunc='sum')

# %%
pd.pivot_table(data=data,values='votes',index='Family',aggfunc='sum')

# %%
pd.pivot_table(data=data,values='votes',index='Mystery',aggfunc='sum')

# %%
pd.pivot_table(data=data,values='votes',index='Sci-Fi',aggfunc='sum')

# %%
pd.pivot_table(data=data,values='votes',index='Thriller',aggfunc='sum')

# %%
data.columns

# %%
d=pd.pivot_table(data=data,values='votes',index='Fantasy',aggfunc='sum')
d

# %%
l=['Action','Adventure', 'Comedy', 'Crime', 'Family', 'Fantasy', 'Mystery','Sci-Fi', 'Thriller']
votes_by_genre=[]
for i in l:
    votes_by_genre.append(pd.pivot_table(data=data,values='votes',index=i,aggfunc='sum')['votes'][True])

# %%
df=pd.DataFrame({'genre':l,'Popularity':votes_by_genre})
df

# %%
df.sort_values(by='Popularity',ascending=False)

# %% [markdown]
# Most Popular genre is Action

# %% [markdown]
# What are the trends in popularity for each game genre?

# %%
import seaborn as sns
plt.figure(figsize=(8,5))
ax=sns.barplot(df['genre'],df['Popularity'])
