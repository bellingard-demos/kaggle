# %%
import numpy as np
import pandas as pd

import jo_wilder
env = jo_wilder.make_env()
iter_test = env.iter_test()

# %%
all_lvgp_at_once_leak = False

for (test, sample_submission) in iter_test:
#     n_lvgps_per_sess = test["level_group"].nunique()
#     if n_lvgps_per_sess > 1:
#         all_lvgp_at_once_leak = True
        
#     if all_lvgp_at_once_leak:
#         sample_submission['correct'] = 1
#     else:
    sample_submission['correct'] = 0
    
    env.predict(sample_submission)

# %%
print(sample_submission["correct"].mean())
