# %%
import copy

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
path = r'../input/fashion-and-beauty-reviews/review_test_post.tsv'
# path = r'../input/fashion-and-beauty-reviews/review_train.tsv'

# %%
data = pd.read_csv(path, sep='\t')
data = data.reset_index()

# %%
output_data = copy.deepcopy(data[['index']])
output_data.columns = ['id']
output_data['id'] = output_data['id'] + 1

# %%
output_data['rating'] = 3.967641914612185

length_of_review = np.nan_to_num(np.array(data.review.str.len()).reshape(-1, 1), 0)
rating = length_of_review * -0.00011505976981671172
rating = rating + 3.9867022384781006
output_data['rating'] = rating
# -0.00011505976981671172 3.9867022384781006

# %%
output_data.to_csv('submission.csv', index=False)

# %%
output_data

# %%
# train_path = r'../input/fashion-and-beauty-reviews/review_train.tsv'

# %%
# train_data = pd.read_csv(train_path, sep='\t')
# train_data = train_data.reset_index()

# %%
# train_data.rating.mean()

# %%
train_data.review.str.len()

# %%
plt.scatter(train_data.review.str.len(), train_data.rating)

plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression()
linear_model.fit(np.nan_to_num(np.array(train_data.review.str.len()).reshape(-1, 1), 0),
                 train_data.rating)

# %%
print(linear_model.coef_[0], linear_model.intercept_)
