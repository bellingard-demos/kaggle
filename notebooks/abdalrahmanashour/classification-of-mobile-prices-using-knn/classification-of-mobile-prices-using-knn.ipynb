# %% [markdown]
# # Data Attributes
#
# * In this data:
#     * id:ID
#     * battery_power:Total energy a battery can store in one time measured in mAh
#     * blue:Has bluetooth or not
#     * clock_speed:speed at which microprocessor executes instructions
#     * dual_sim:Has dual sim support or not
#     * fc:Front Camera mega pixels
#     * four_g:Has 4G or not
#     * int_memory:Internal Memory in Gigabytes
#     * m_dep:Mobile Depth in cm
#     * mobile_wt:Weight of mobile phone
#     * n_cores:Number of cores of processor
#     * pc:Primary Camera mega pixels
#     * px_height:Pixel Resolution Height
#     * px_width:Pixel Resolution Width
#     * ram:Random Access Memory in Megabytes
#     * sc_h:Screen Height of mobile in cm
#     * sc_w:Screen Width of mobile in cm
#     * talk_time:longest time that a single battery charge will last when you are
#     * three_g:Has 3G or not
#     * touch_screen:Has touch screen or not
#     * wifi:Has wifi or not

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Loading Training Data

# %%
train_df = pd.read_csv('../input/mobile-price-classification/train.csv')

# %% [markdown]
# ## Describe Training Data

# %%
train_df.shape

# %%
train_df.describe()

# %%
train_df.info()

# %%
train_df.head(10)

# %% [markdown]
# ## Check for null values

# %%
train_df.isnull().sum()

# %% [markdown]
# ## Visualize Some Relations

# %%
#plt.figure(figsize = (25,10))
sns.barplot(x = 'price_range', y = 'battery_power', data=train_df)
plt.show()

# %%
#plt.figure(figsize = (25,10))
sns.barplot(x = 'price_range', y = 'ram',data=train_df)
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# prepare training data 
# x for all the training data without "price range"
# y for "price range"

# %%
# Split training data into train and test
# test_size = ?
# random_state = ?

# %% [markdown]
# ## Using KNN Algorithm

# %%
# determine number of neighbours
# fit the KNN algorithm

# %%
# score the training process

# %%
# predict y values for x_test and assigning its vakues for a variable called predictions

# %%
# score the accuracy for y_test and predictions

# %% [markdown]
# ## Predicting values for Test Data

# %%
# load test data into a dataframe called "test_df"

# %%
# show its shape

# %%
# drop "id" column

# %%
# predict its price range and assign its value to variable called "predicted_price_range"

# %%
# add "predicted_price_range" to the test_df

# %%
# display the head of test_df
