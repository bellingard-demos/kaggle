# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread("/kaggle/input/resources/cv_cover.jpg")
plt.imshow(image)

# %%
image2 = cv2.imread("/kaggle/input/resources/l1.png")
plt.imshow(image2)
