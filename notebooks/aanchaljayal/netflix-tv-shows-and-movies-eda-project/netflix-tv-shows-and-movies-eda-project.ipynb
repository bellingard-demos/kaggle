# %% [markdown]
# # **Analysis on Netflix Tv shows and Movies**
#
# Netflix is a popular entertainment service used by people around the world. This EDA will explore the Netflix dataset through visualizations and graphs using python libraries, matplotlib.
#
# I have used TV Shows and Movies listed on the Netflix dataset from Kaggle.

# %% [markdown]
# **Importing the libraries we need for this project**

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Now we will use Pandas Library, to read CSV file**

# %%
df = pd.read_csv("/kaggle/input/netflix-shows/netflix_titles.csv")
df.head()

# %% [markdown]
# # Data Cleaning

# %%
df.columns     #find name of the columns

# %%
df.shape     #find shape of the data

# %%
df.describe()    #find out basic stats

# %%
df.info()     #information regarding the data

# %% [markdown]
# **To find out the null values**

# %%
df.isnull().sum()

# %% [markdown]
# **removing null values**

# %%
df.dropna(inplace = True)    #it will remove all the null values available in the dataset
df                           #inplace is used for permanent change

# %%
df.head()

# %% [markdown]
# # Exploratory Analysis & Visualization
# Now our data is properly ready for use
#
# **1.Netflix content By Type**
#
# let"s compare the total number of movies and Tv shows in this dataset to know which one is the majority

# %%
plt.figure(figsize=(12,4))
plt.title("Percentation of Movies or TV Shows")
g = plt.pie(df.type.value_counts(),explode=(0.025,0.025), labels=df.type.value_counts().index, colors=['red','black'],autopct='%1.1f%%', startangle=180)
plt.show()

# %% [markdown]
# So,we can see that 97.2% audience prefer movies over tv shows

# %% [markdown]
# **2.In which year the netflix releases the most movies and tv shows?**

# %%
plt.figure(figsize = (12,5))
sns.countplot(x = 'release_year',order = df['release_year'].value_counts().index[0:10],data = df,palette = 'mako')
plt.title('count release in years on netflix v/s count')

# %% [markdown]
# **3.Top 10 directors on Netflix**

# %%
filtered_directors = df[df.director != 'No Director'].set_index('title').director.str.split(', ', expand=True).stack().reset_index(level=1, drop=True)
plt.figure(figsize=(13,7))
plt.title('Top 10 Director Based on The Number of Titles')
sns.countplot(y = filtered_directors, order=filtered_directors.value_counts().index[:10], palette='pink')
plt.show()

# %% [markdown]
# **4.Amount of content netflix has added throughout the year**

# %%
df_year = df.groupby(['release_year']).agg({'title':'nunique'}).reset_index()
plt.figure(figsize = (12,6))
sns.lineplot(x='release_year',y = 'title',data=df_year,color = 'blue')
plt.xticks(rotation = 60)
plt.title('Total content added throughout the year')

# %% [markdown]
# **5.Top 15 geners being most watched on netflix**

# %%
filtered_genres = df.set_index('title').listed_in.str.split(', ', expand=True).stack().reset_index(level=1, drop=True);
plt.figure(figsize=(10,10))
g = sns.countplot(y = filtered_genres, order=filtered_genres.value_counts().index[:15])
plt.title('Top 20 Genres on Netflix')
plt.xlabel('Titles')
plt.ylabel('Genres')
plt.show()

# %% [markdown]
# # Conclusion
#
# After conducting an EDA project on the netflix dataset,we can draw many interestinf inferences and conclusions:
#
# 1.movies is the most common type of content on Netflix.
#
# 2.the year 2017 is highest of the release the movies and tv shows followed by 2018 is 2nd highest.
#
# 3.the most popular director on netflix is jan suter.
#
# 4.the mostly like geners by the public is international movies,dramas,comedy,and action & adventure.
#
# 5.the amount of content across netflix has started slowly from 1940 and then till 2019 the content is on peak.then started decreasing from here.
