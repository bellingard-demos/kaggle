# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # **** Import Library

# %%
# Data Analysis
import numpy as np 
import pandas as pd

#........................
# visualization
import seaborn as sns
import matplotlib .pyplot as plt 
# %matplotlib inline

#........................
#import library for machine learning
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')
from sklearn .preprocessing import StandardScaler
from scipy.stats import norm
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_squared_error
from sklearn.feature_selection import SelectFromModel
from sklearn.impute import SimpleImputer

# %% [markdown]
# # ****Read Data

# %%
data = pd.read_csv("../input/used-car-dataset-ford-and-mercedes/ford.csv")

# %%
print(data.shape)
data.head()

# %% [markdown]
# # ****Analyze data before processing

# %%
print(data.columns.values)

# %%
data.info()

# %%
# Knowing some statistical values
data.describe()

# %%
## checking for null values.
print(data.isnull().sum())

# %%
# Show the sum of duplicated in Data 
DuplicatedDataSum = data.duplicated().sum()
print("Sum of the Dublicate in Data",DuplicatedDataSum)

# %%
DuplicatedData = data.duplicated()
print(DuplicatedData)

# %%
##Delete the duplicate data 
data = data.drop_duplicates()
# Show the sum of duplicated in Data 
DuplicatedDataSum = data.duplicated().sum()
print("Sum of the Dublicate in Data",DuplicatedDataSum)

# %% [markdown]
# # ****Calculate the correlation between Data and Draw The Data

# %% [markdown]
# First Calculate the Correlation

# %%
#Show the correlation between data 
corr = data.corr()
corr

# %% [markdown]
# Second Draw thw correlation

# %%
## Draw the RelationShip between Data 

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))
# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
## Draw the RelationShip between Data ((correlation))

plt.figure(figsize=(15,10))
sns.heatmap(corr,annot=True)

# %% [markdown]
# # pandas_profiling library

# %%
from pandas_profiling import ProfileReport 

profile = ProfileReport( data, title='Pandas profiling report ' , html={'style':{'full_width':True}})

profile.to_notebook_iframe()

# %% [markdown]
# # ****Convert the columns that containing the string to numerical Values

# %%
## convert the "Model" column
le = LabelEncoder()
le.fit(data['model'])
le.transform(data['model'])
data['model'] = le.transform(data['model'])

# %%
## convert the "transmission" column
le = LabelEncoder()
le.fit(data['transmission'])
le.transform(data['transmission'])
data['transmission'] = le.transform(data['transmission'])

# %%
# ## convert the "fuelType" column
le = LabelEncoder()
le.fit(data['fuelType'])
le.transform(data['fuelType'])
data['fuelType'] = le.transform(data['fuelType'])

# %%
data.head()

# %% [markdown]
# # ****Calculate The correlation and draw the relationShip between one input and Output

# %% [markdown]
# calculate the correlation between the column (Model) and the output (price)

# %%
model = np.corrcoef(data['model'],data['price'])
model

# %% [markdown]
# Draw the correlation and confusion Matrix to the column (model) and output

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5), sharex=True)
sns.kdeplot(data=model, ax=ax1)
sns.heatmap(model,annot=True,ax= ax2)

# %% [markdown]
# calculate the correlation between the column (year) and the output (price)

# %%
year = np.corrcoef(data['year'],data['price'])
year

# %% [markdown]
# Draw the correlation and confusion Matrix to the column (year) and output

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5), sharex=True)
sns.kdeplot(data=year, ax=ax1)
sns.heatmap(year,annot=True,ax= ax2)

# %% [markdown]
# calculate the correlation between the column (transmission) and the output (price)

# %%
transmission = np.corrcoef(data['transmission'],data['price'])
transmission

# %% [markdown]
# Draw the correlation and confusion Matrix to the column (transmission) and output

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5), sharex=True)
sns.kdeplot(data=transmission, ax=ax1)
sns.heatmap(transmission,annot=True,ax= ax2)

# %% [markdown]
# calculate the correlation between the column (mileage) and the output (price)

# %%
mileage = np.corrcoef(data['mileage'],data['price'])
mileage

# %% [markdown]
# Draw the correlation and confusion Matrix to the column (mileage) and output

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5), sharex=True)
sns.kdeplot(data=mileage, ax=ax1)
sns.heatmap(mileage,annot=True,ax= ax2)

# %% [markdown]
# calculate the correlation between the column (fuelType) and the output

# %%
fuelType = np.corrcoef(data['fuelType'],data['price'])
fuelType

# %% [markdown]
# Draw the correlation and confusion Matrix to the column (fuelType) and output

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5), sharex=True)
sns.kdeplot(data=fuelType, ax=ax1)
sns.heatmap(fuelType,annot=True,ax= ax2)

# %% [markdown]
# calculate the correlation between the column (tax) and the output

# %%
tax = np.corrcoef(data['tax'],data['price'])
tax

# %% [markdown]
# Draw the correlation and confusion Matrix to the column (tax) and output

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5), sharex=True)
sns.kdeplot(data=tax, ax=ax1)
sns.heatmap(tax,annot=True,ax= ax2)

# %% [markdown]
# calculate the correlation between the column (mpg) and the output

# %%
mpg =  np.corrcoef(data['mpg'],data['price'])
mpg

# %% [markdown]
# Draw the correlation and confusion Matrix to the column (mpg) and output

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5), sharex=True)
sns.kdeplot(data=mpg, ax=ax1)
sns.heatmap(mpg,annot=True,ax= ax2)

# %% [markdown]
# calculate the correlation between the column (engineSize) and the output

# %%
engineSize = np.corrcoef(data['engineSize'],data['price'])
engineSize

# %% [markdown]
# Draw the correlation and confusion Matrix to the column (engineSize) and output

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5), sharex=True)
sns.kdeplot(data=engineSize, ax=ax1)
sns.heatmap(engineSize,annot=True,ax= ax2)

# %%
import seaborn as sns; sns.set_theme(color_codes=True)

ax = sns.regplot(x="year", y="price", data=data)

# %%
sns.relplot(data=data, x="year", y="price", hue="year")

# %%
 sns.lmplot(x="year", y="price", hue="year", data=data)

# %%
data.head()

# %%
# fig, ax = sns.subplots(2,4,figsize=(30,20))
# ax[0,0].lmplot(x="model", y="price", hue="model", data=data)
# ax[0,1].lmplot(x="year", y="price", hue="year", data=data)
# ax[0,2].lmplot(x="transmission", y="price", hue="transmission", data=data)
# ax[0,3].lmplot(x="mileage", y="price", hue="mileage", data=data)
# ax[1,0].lmplot(x="fuelType", y="price", hue="fuelType", data=data)
# ax[1,1].lmplot(x="tax", y="price", hue="tax", data=data)
# ax[1,2].lmplot(x="mpg", y="price", hue="mpg", data=data)
# ax[1,3].lmplot(x="engineSize", y="price", hue="engineSize", data=data)

# %%
# fig, axes = plt.subplots(2, 4, figsize=(18, 10))

# fig.suptitle('Pokemon Stats by Generation')

# sns.lmplot(ax=axes[0, 0], x="model", y="price", hue="model", data=data)
# sns.lmplot(ax=axes[0, 1],x="year", y="price", hue="year", data=data)
# sns.lmplot(ax=axes[0, 2],x="transmission", y="price", hue="transmission", data=data)
# sns.lmplot(ax=axes[0, 3],x="mileage", y="price", hue="mileage", data=data)
# sns.lmplot(ax=axes[1, 0],x="fuelType", y="price", hue="fuelType", data=data)
# sns.lmplot(ax=axes[1, 1],x="tax", y="price", hue="tax", data=data)
# sns.lmplot(ax=axes[1, 2],x="mpg", y="price", hue="mpg", data=data)
# sns.lmplot(ax=axes[1, 3],x="engineSize", y="price", hue="engineSize", data=data)

# %%
# f, (ax0, ax1,ax2,ax3,ax4,ax5,ax6,ax7) = plt.subplots(2, 4, sharey=True)
# sns.lmplot(ax=ax0, x="model", y="price", hue="model", data=data)
# sns.lmplot(ax=ax1,x="year", y="price", hue="year", data=data)
# sns.lmplot(ax=ax2,x="transmission", y="price", hue="transmission", data=data)
# sns.lmplot(ax=ax3,x="mileage", y="price", hue="mileage", data=data)
# sns.lmplot(ax=ax4,x="fuelType", y="price", hue="fuelType", data=data)
# sns.lmplot(ax=ax5,x="tax", y="price", hue="tax", data=data)
# sns.lmplot(ax=ax6,x="mpg", y="price", hue="mpg", data=data)
# sns.lmplot(ax=ax7,x="engineSize", y="price", hue="engineSize", data=data)
