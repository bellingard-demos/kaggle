# %% [markdown]
# <div style="width:100%;text-align: center;"> <img align=middle src="https://images.unsplash.com/photo-1588931929796-8f0ea6da0faa?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxzZWFyY2h8NXx8aGFydW1hbmlzJTIwbWFuZ298ZW58MHwwfDB8fA%3D%3D&auto=format&fit=crop&w=500&q=60" alt="Heat beating" style="height:366px;margin-top:3rem;"> </div>

# %% [markdown]
# # <h1 style='background:#FFC300; border:0; color:white'><center>🥭Harumanis Mango Classification</center></h1>

# %% [markdown]
# # **<span style="color:#FFC300;">📰About the Dataset</span>**
#
# Mango is the king of fruits. Harumanis Mangoes are one of the best mangoes in the world produced in the smallest state in the Northern tip of Malaysia - Perlis. Whilst most of our Harumanis Mangoes are exported to Japan, Singapore and the rest of the world each year, we aim to bring them to fellow Malaysians.Unlike every other mangoes, Harumanis Mangoes have a distinct taste. They have a slightly creamy and milky taste and a very strong and distinct aroma.
#
# # **<span style="color:#FFC300;">📁About the files</span>**
#
# This dataset consists of 5 columns:
#
# Unique id
#
# Weight
#
# Length
#
# Circumference
#
# Grade

# %%
# Imports
import sklearn
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
#Environment check
import os
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## **<span style="color:#cd486b;">📃 Let's get the data</span>**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('/kaggle/input/harumanis-mango-physical-measurement/Data.csv')

# %%
df.describe()

# %%
df.info()

# %%
df.head()

# %%
df.columns

# %%
df.drop('No',axis = 1, inplace = True)

# %%
df['Grade'] = df['Grade'].str.replace('A', '0')
df['Grade'] = df['Grade'].str.replace('B', '1')

# %%
df['Grade'] = df['Grade'].astype(int)

# %% [markdown]
# ## **<span style="color:#cd486b;">🪓 Let's split the dataset</span>**

# %%
X = df.iloc[:,:-1]
y = df['Grade']

# %%
X.shape

# %%
y.shape

# %%
#Check for imbalanced data
y.value_counts()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, test_size = 0.2, stratify = y)

# %% [markdown]
# ## **<span style="color:#cd486b;">🎎 Define your Model</span>**

# %%
model = RandomForestClassifier()

# tried n_estimators = 100, but did not make a great difference

# %%
#Fit model
model.fit(X_train, y_train)

# %% [markdown]
# ## **<span style="color:#cd486b;">🔮 Predictions</span>**

# %%
#Make predictions
predictions = model.predict(X_test)

# %%
type(predictions[0])

# %% [markdown]
# ## **<span style="color:#cd486b;">🔢Metrics</span>**

# %% [markdown]
# ## **<span style="color:#FFC300;">Mean Absolute Error</span>**

# %%
#Mean absolute error

mae = mean_absolute_error(predictions, y_test)
print("Mean Absolute Error with  Random Forest classifier:" , mae)

# %% [markdown]
# ## **<span style="color:#FFC300;">Accuracy</span>**

# %%
#Accuracy

accuracy = metrics.accuracy_score(y_test,predictions)
print('Accuracy for Random Forest classifier model is - ', accuracy)

# %% [markdown]
# ## **<span style="color:#FFC300;">Precision</span>**

# %%
#Precision

precision_score = sklearn.metrics.precision_score(y_test, predictions, labels=model.classes_)
print("Precision score for Random Forest Classifier is  ", precision_score)

# %% [markdown]
# ## **<span style="color:#FFC300;">Classification Report</span>**

# %%
#Classification Report

clf_report = classification_report(y_test, predictions)
print(clf_report)

# %% [markdown]
# ## **<span style="color:#FFC300;">Confusion Matrix</span>**

# %%
#Confusion Matrix

cm = confusion_matrix(y_test, model.predict(X_test), labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=model.classes_)
disp.plot()

# %% [markdown]
# **From the above classification report and confusion matrix, we found that our model is performing well on both training and test sets. Also, the confusion matrix looks quite appropriate for a small dataset like used in this notebook.**

# %% [markdown]
# # **<span style="color:#cd486b;">🤘Conclusion</span>**
#
# From above analysis, we found that we can solve this classification problem using Random Forest Classifier with 86% accuracy and precision score. Further, we can use XGBoost and its variations to get better accuracy.
#
# > **This marks the end of 🥭Harumanis Mango Classification**
#
# > **Stay Tuned for more..**
#
# > **Please share your feedback and suggestions and help me improve 😇**
