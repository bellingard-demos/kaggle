# %% [markdown]
# <div style="width:100%;text-align: center;"> <img align=middle src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTZDPPKInyoUywLKibce3PnFm6M15tj2xZ0NQ&usqp=CAU"Heat beating" style="height:400px;margin-top:3rem;"> </div>

# %% [markdown]
# # <h1 style='background:#D8101D; border:0; color:white'><center> 🛒 EDA: Jio Mart Product Items </center></h1>

# %% [markdown]
# # **<span style="color:#FAC700;">📰About the Dataset</span>**
#
# The data is crawled from JioMart website and stored in a parquet file named jio_mart_items.parquet. The file contains a total of 158172 product items and 5 columns.
#
# # **<span style="color:#FAC700;">📁About the files</span>**
#
# > category: category of the product item as on the site
#
# > sub_category: sub-category of the product item as on the site
#
# > href: product item link
#
# > items: product item name
#
# > price: product item's price

# %%
#Imports
import matplotlib.pyplot as plt
import seaborn as sns

#Custom Colors
class clr:
    S = '\033[1m' + '\033[96m'
    E = '\033[0m'
    
my_colors = ["#D8101D","#0B7900", "#003892", "#00D7FF", "#FAC700"]

print(clr.S + "Notebook Color Scheme: " + clr.E)
sns.palplot(sns.color_palette(my_colors))

# %%
#Environment check
import os
import warnings
warnings.filterwarnings("ignore")

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('/kaggle/input/jio-mart-product-items/jio_mart_items.csv')

# %%
df.info()

# %%
df.describe()

# %%
df.columns

# %%
df.head()

# %% [markdown]
# # **<span style="color:#FFC54D;">🥽Let's see what all we can explore in this dataset</span>**
#
# > 1. Correlation among all parameters
#
# > 2. We can find the number of categories and subcategories.
#
# > 3. Which is the most priced product
#
# > 4. Get image of the most priced product using href.

# %% [markdown]
# ## **<span style="color:#003892;"> 1️⃣ Correlation among all parameters</span>**

# %%
plt.figure(figsize = (15, 8), facecolor = "#F7F4F4")
sns.heatmap(df.corr(), annot = True, cmap = "gist_heat");

# %% [markdown]
# **<span style="color:#00D7FF;">There is no corelation between any of these parameters.</span>**

# %% [markdown]
# ## **<span style="color:#003892;"> 2️⃣ Find the number of categories and subcategories.</span>**

# %%
no_of_categories = df.category.unique()
no_of_subcategories = df.sub_category.unique()
print("There are ", len(no_of_categories), " categories and ", len(no_of_subcategories), " sucategories")

# %%
plt.plot(no_of_categories, color = my_colors[1])

# %%
plt.figure(figsize=(15,8))
year_club = df.groupby(['category', 'sub_category']).category.value_counts().head(20).plot(kind = 'bar',color = my_colors[3])
plt.title('Items and their prices')
plt.legend()
plt.show()

# %% [markdown]
# ## **<span style="color:#003892;"> 3️⃣ Which is the most priced product</span>**

# %%
max_price = df['price'].max()
max_price_item = df.loc[df['price'] == max_price, 'items'].value_counts().plot(kind = 'barh', color = my_colors[2])
plt.title('Product with highest price')
plt.show()

# %%
print("Most costly item on Jio Mart are Pinak stores Black Ear wired Earphones with mic having a price of Rs",max_price)

# %% [markdown]
# **<span style="color:#00D7FF;">Pinak stores Black Ear wired Earphones with mic are apparently the most costly product on Jio Mart.</span>**

# %% [markdown]
# ## **<span style="color:#003892;"> 4️⃣ Get image of the most priced product using href.</span>**

# %%
print(df['href'].head())

# %%
#from IPython.display import Image
#Image("https://www.jiomart.com/images/product/600x600/590009785/tender-coconut-3-pcs-product-images-o590009785-p591041745-0-202203171040.jpg")

# %% [markdown]
# <div style="width:100%;text-align: center;"> <img align=middle src="https://www.jiomart.com/images/product/600x600/590009785/tender-coconut-3-pcs-product-images-o590009785-p591041745-0-202203171040.jpg" style="height:400px;margin-top:3rem;"> </div>

# %% [markdown]
# **<span style="color:#00D7FF;">Since, the href's given in the dataset tend to give 403 error. Hence, we could find out some data from fruits and vegetables section via Jio mart website as presented above.</span>**

# %% [markdown]
# # **<span style="color:#cd486b;">🤘Conclusion</span>**
# From the dataset provided, we found some facts about the priciest items, categories and sub categories they fall into and more. However the dataset is quite limited to explore more horizons. I look forward to updates in this dataset and explore more.
#
# **<span style="color:#000000;">This marks the end of 🛒EDA: Jio Mart Product Items</span>**
#
# **<span style="color:#000000;"> Stay Tuned for more..</span>**
#
# **<span style="color:#000000;">Please share your feedback and suggestions and help me improve 😇 </span>**
