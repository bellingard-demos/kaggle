# %% [markdown]
# <div style="width:100%;text-align: center;"> <img align=middle src="https://images.unsplash.com/photo-1619881589670-43629f0e90f1?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxzZWFyY2h8Nnx8bWNkb25hbGR8ZW58MHwwfDB8fA%3D%3D&auto=format&fit=crop&w=500&q=60" alt="Heat beating" style="height:366px;margin-top:3rem;"> </div>

# %% [markdown]
# # <h1 style='background:#DA291C; border:0; color:white'><center>🍔🍟EDA: McDonald's India- Menu Nutrition Facts</center></h1>

# %% [markdown]
# # **<span style="color:#FFC72C;">📰About the Dataset</span>**
#
# McDonald’s in India was started in 1996 in Bandra, Mumbai with one single restaurant. It took almost twelve years to grow one restaurant to 50. Today, McDonald's, that arrived in India without its signature Big Mac (substituted in India by the Maharaja Mac) has about 480 stores all over India providing happy meals to folks and families of India.This dataset provides a nutrition analysis of every menu item on the Indian McDonald's menu, including breakfast, burgeres, fries, salads, soda, coffee and tea, milkshakes, and desserts.
#
# # **<span style="color:#FFC72C;">📁About the file</span>**
#
# There are 13 columns in the csv file, namely:
#
# Menu Category',
#
# 'Menu Items',
#
# 'Per Serve Size',
#
# 'Energy (kCal)',
#
# 'Protein (g)',
#
# 'Total fat (g)',
#
# 'Sat Fat (g)',
#
# 'Trans fat (g)',
#
# 'Cholesterols (mg)',
#
# 'Total carbohydrate (g)',
#
# 'Total Sugars (g)',
#
# 'Added Sugars (g)',
#
# 'Sodium (mg)'

# %%
#Imports
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

#Custom Colors
class clr:
    S = '\033[1m' + '\033[96m'
    E = '\033[0m'
    
my_colors = ["#FFC72C","#DA291C", "#B56576", "#E56B6F", "#EAAC8B"]

print(clr.S + "Notebook Color Scheme: " + clr.E)
sns.palplot(sns.color_palette(my_colors))

# %%
#Environment check
import os
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## **<span style="color:#cd486b;">📃 Let's get the data</span>**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('/kaggle/input/mcdonalds-india-menu-nutrition-facts/India_Menu.csv')

# %%
df.info()

# %%
df.describe()

# %%
df.head()

# %%
df.columns

# %%
#Check for null values 
df.isna().any()

# %%
df.replace('Nan',np.nan, inplace = True)

# %%
df.dropna(axis = 0, inplace = True)

# %%
df.isna().any()

# %% [markdown]
# ## **<span style="color:#FFC72C;">🥽Let's see what all we can</span>** **<span style="color:#DA291C;"> explore in this dataset</span>**
#
# > Which Menu Item has least and max Energy (kCal)?
#
# > Which item has min / max serve size?
#
# > Which item has least and most total fat?
#
# > Which item has least and most Cholestrol?
#
# > Which item has min/max sugars?
#
# > Which item has most sodium?
#
# > Which menu category has max items?

# %% [markdown]
# ## **<span style="color:#DA291C;">Which Menu Item has least and max Energy (kCal)?</span>**

# %%
min_energy = df['Energy (kCal)'].min()
min_energy_item = df.loc[df['Energy (kCal)'] == min_energy, 'Menu Items'].iloc[0]
print("Menu item: ", min_energy_item, " has least energy of: ", min_energy, "kCal")

# %%
max_energy = df['Energy (kCal)'].max()
max_energy_item = df.loc[df['Energy (kCal)'] == max_energy, 'Menu Items'].iloc[0]
print("Menu item: ", max_energy_item, " has most energy of: ", max_energy, "kCal")

# %% [markdown]
# ## **<span style="color:#FFC72C;">Which item has min / max serve size?</span>**

# %%
df['Per Serve Size'] = df['Per Serve Size'].map(lambda x: x.lstrip(' g').rstrip(' g'))
df['Per Serve Size'] = df['Per Serve Size'].map(lambda x: x.lstrip(' ml').rstrip(' ml'))

# %%
df['Per Serve Size'].head()

# %%
df['Per Serve Size'].unique()

# %%
df['Per Serve Size'] = df['Per Serve Size'].astype(float)

# %%
min_serve_size = df['Per Serve Size'].min()
min_serve_item = df.loc[df['Per Serve Size'] == min_serve_size, 'Menu Items'].iloc[0]
print("Menu item: ", min_serve_item, " has least serve size of: ", min_serve_size, "g")

# %%
max_serve_size = df['Per Serve Size'].max()
max_serve_item = df.loc[df['Per Serve Size'] == max_serve_size, 'Menu Items'].iloc[0]
print("Menu item: ", max_serve_item, " has max serve size of: ", max_serve_size, "ml")

# %% [markdown]
# ## **<span style="color:#DA291C;">Which item has least and most total fat?</span>**

# %%
min_fat = df['Total fat (g)'].min()
min_fat_item = df.loc[df['Total fat (g)'] == min_fat, 'Menu Items'].iloc[0]
print("Menu item: ", min_fat_item, " has min fat i.e: ", min_fat, "g")

# %%
max_fat = df['Total fat (g)'].max()
max_fat_item = df.loc[df['Total fat (g)'] == max_fat, 'Menu Items'].iloc[0]
print("Menu item: ", max_fat_item, " has max fat i.e:",max_fat, "g")

# %% [markdown]
# ## **<span style="color:#FFC72C;">Which item has least and most Cholestrol?</span>**

# %%
min_chol = df['Cholesterols (mg)'].min()
min_chol_item = df.loc[df['Cholesterols (mg)'] == min_chol, 'Menu Items'].iloc[0]
print("Menu item: ", min_chol_item, " has min Cholestrol of:  ", min_chol, "mg")

# %%
max_chol = df['Cholesterols (mg)'].max()
max_chol_item = df.loc[df['Cholesterols (mg)'] == max_chol, 'Menu Items'].iloc[0]
print("Menu item: ", max_chol_item, " has max cholestrol of: ", max_chol, "mg")

# %% [markdown]
# ## **<span style="color:#DA291C;">Which item has min/max sugars?</span>**

# %%
min_sugar = df['Total Sugars (g)'].min()
min_sugar_item = df.loc[df['Total Sugars (g)'] == min_sugar, 'Menu Items'].iloc[0]
print("Menu item: ", min_sugar_item, " has least sugar i.e: ", min_sugar, "g")

# %%
max_sugar = df['Total Sugars (g)'].max()
max_sugar_item = df.loc[df['Total Sugars (g)'] == max_sugar, 'Menu Items'].iloc[0]
print("Menu item: ", max_sugar_item, " has max sugar i.e: ",max_sugar, "g")

# %% [markdown]
# ## **<span style="color:#FFC72C;">Which item has most sodium?</span>**

# %%
min_sodium = df['Sodium (mg)'].min()
min_sodium_item = df.loc[df['Sodium (mg)'] == min_sodium, 'Menu Items'].iloc[0]
print("Menu item: ", min_sodium_item, " has least sodium i.e: ", min_sodium, "mg")

# %%
max_sodium = df['Sodium (mg)'].max()
max_sodium_item = df.loc[df['Sodium (mg)'] == max_sodium, 'Menu Items'].iloc[0]
print("Menu item: ", max_sodium_item, " has max sodium i.e: ",max_sodium, "mg")

# %% [markdown]
# ## **<span style="color:#DA291C;">Which menu category has max items?</span>**

# %%
Categories = df['Menu Category'].value_counts()
Categories

# %%
plt.figure(figsize = (15,8))
Categories.plot(kind = "bar", color= my_colors[4])
plt.show()

# %% [markdown]
# **<span style="color:#E56B6F;">From the above analysis, we can say that MCDonalds India does not have much Desserts on their menu. Instead, they do have a large variety of options to try from their McCafe Menu.</span>**

# %% [markdown]
# # **<span style="color:#cd486b;">🤘Conclusion</span>**
#
# From the above analysis the best meal to suggest would be a
#
# - A L1 coffee
#
# - 6 piece Chicken McNuggets
#
# - With some  Piri Piri Mix
#
# **<span style="color:#000000;">This marks the end of 🍔🍟EDA: McDonald's India- Menu Nutrition Facts</span>**
#
# **<span style="color:#000000;"> Stay Tuned for upcoming versions..</span>**
#
# **<span style="color:#000000;">Please share your feedback and suggestions and help me improve 😇 </span>**
