# %% [markdown]
# <div style="width:100%;text-align: center;"> <img align=middle src="https://media.tenor.com/ueWhd-6BW5cAAAAM/fran-healy-travis.gif" alt="Heat beating" style="height:366px;margin-top:3rem;"> </div>

# %% [markdown]
# # <span style='color:aliceblue'><center style='background:#0F3460;border-radius:0px 25px;padding:25px'> 📱EDA: Analyzing Screen Time </center></span>

# %% [markdown]
# # **<span style="color:#E94560;">📰About the Dataset</span>**
#
# This dataset contains the usage statistics of various apps on a phone.
#
# The dataset contains 5 columns:
#
# > 1. Date
#
# > 2. Usage
#
# > 3. Notifications
#
# > 4. Times Opened
#
# > 5. App

# %%
#imports

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Environment check
import os
import warnings
warnings.filterwarnings("ignore")

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('/kaggle/input/analyzing-screen-time/Screentime - Overall Usage.csv')

# %%
df.head()

# %%
df.columns

# %% [markdown]
# ## **<span style="color:#E94560;">👀Let's Analyse</span>**

# %% [markdown]
# <div style="width:100%;text-align: center;"> <img align=middle src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSA_Xzo-lworWNHN1gSdum9rQUU7fWu24MlP99XszewySvZvUbblURRxJ8rjuJ_aoPSa-Q&usqp=CAU" alt="Heat beating" style="height:366px;margin-top:3rem;"> </div>

# %%
most_unlocks = df['Unlocks'].max()
print(most_unlocks)

corelated_notifications = df.loc[df['Unlocks'] == most_unlocks, 'Notifications'].iloc[0]
print('No. of times user got notification = ', corelated_notifications, ' Max number of unlocks to their phone =', most_unlocks)

# %%
most_notifications = df['Notifications'].max()
corelated_unlocks = df.loc[df['Notifications'] == most_notifications, 'Unlocks'].iloc[0]
print('No. of times user unlocked phone = ', corelated_unlocks, ' No. of max notifications =', most_notifications)

# %% [markdown]
# The above data shows that even the number of notifications where far greater than number of most unlocks or any unlocks. The number of time a user unlocked a phone to review the notification is less than half the number of notifications. That is a good sign 🙌

# %%
df['Date ']= df['Date '].astype("datetime64")

# %%
plt.style.use("dark_background") # fivethirtyeight
df.plot(subplots=True, figsize=(12, 15))
plt.xlabel('Values')

# %%
sorted_df = df.sort_values(by=['Total Usage'], ascending = False)
sorted_df.head()

# %%
plt.figure(figsize=(15,8))
plt.style.use("dark_background")
sns.barplot(x='Date ',y='Total Usage', data = sorted_df.head(20))
#sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.yticks(fontsize= 6)
plt.ylabel('Total Usage')
plt.xlabel('Date')
plt.xticks(rotation = 60)
plt.title('Total Usage per Day')

# %% [markdown]
# # <span style='color:aliceblue'><center style='background:#0F3460;border-radius:0px 25px;padding:25px'>Analysis of Apps </center></span>

# %% [markdown]
# <div style="width:100%;text-align: center;"> <img align=middle src="https://media.tenor.com/GJNinMsIz0YAAAAM/dance-deekay.gif" alt="Heat beating" style="height:366px;margin-top:3rem;"> </div>

# %%
df1 = pd.read_csv('/kaggle/input/analyzing-screen-time/Screentime - App Details.csv')

# %%
df1.head()

# %%
plt.style.use("dark_background") # fivethirtyeight
df1.plot(subplots=True, figsize=(12, 15))
plt.xlabel('Values')

# %%
df1.columns

# %%
# Which apps were used most often? most opened
max_times = df1['Times opened'].max()
used_app = df1.loc[df1['Times opened'] == max_times, 'App'].iloc[0]

print(used_app, 'was opened max times ~', max_times, 'times')

# %%
# Which app had max usage?

max_usage = df1['Usage'].max()
_app = df1.loc[df1['Usage'] == max_usage, 'App'].iloc[0]

print(_app, 'had maximum usage ~', max_usage)

# %%
# Which app had max notifications?

max_notification = df1['Notifications'].max()
u_app = df1.loc[df1['Notifications'] == max_notification, 'App'].iloc[0]

print(u_app, 'had max notifications ~', max_notification)

# %%
# Which app had least notifications

min_notification = df1['Notifications'].min()
us_app = df1.loc[df1['Notifications'] == min_notification, 'App'].iloc[0]

print(us_app, 'had least notifications ~', min_notification)

# %%
df1['Date']= df1['Date'].astype("datetime64")

# %%
# Relation between Date and times an app was opened

plt.figure(figsize=(15,8))
plt.style.use("dark_background")
sns.barplot(x='Date',y='Times opened', data = df1.head(20))
#sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.yticks(fontsize= 6)
plt.ylabel('Times opened')
plt.xlabel('Date')
plt.xticks(rotation = 60)
plt.title('Total times apps were opened per Day')

# %%
# Count of each app

apps = df1['App'].value_counts()
plt.figure(figsize=(15,8))
plt.bar(apps.index, apps, color=['#FFC4C4', '#F7A76C']) 
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# # **<span style="color:#DA291C;">🤘Conclusion</span>**
#
# > **This marks the end of 📱EDA: Analyzing Screen Time**
#
# > **Stay Tuned for more..**
#
# > **Please share your feedback and suggestions and help me improve 😇**
