# %% [markdown]
# <div style="width:100%;text-align: center;"> <img align=middle src="https://cdn.dribbble.com/users/722843/screenshots/6462327/dribbble.gif" alt="Heat beating" style="height:366px;margin-top:3rem;"> </div>

# %% [markdown]
# # <h1 style='background:#D61C4E; border:0; color:white'><center>👞EDA: Shoe Dataset</center></h1>

# %% [markdown]
# # **<span style="color:#cd486b;">📰About the Dataset</span>**
#
# This is a list of 23,940 men's shoes and their product information collected from Amazon Product Database.
#
# The dataset includes shoe name, brand, price, and more.
#
# # **<span style="color:#cd486b;">📁About the files</span>**
#
# The dataset contains five columns:
#
# > 1.brand_name:-- this columns show brand (company name) for eg:- asiasn,campus,reebook etc
#
# > 2.howmanysold:-- Number of shoe sold
#
# > 3.Current_Price:--price of shoe during purches
#
# > 4.Product_details:--for what purpose we use this for eg:-running ,walkig,jumping etc
#
# > 5.Rating:--out of 5 star how much star given by customer in form of feedback

# %%
# Imports
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Custom Colors
class clr:
    S = '\033[1m' + '\033[96m'
    E = '\033[0m'
    
my_colors = ["#293462", "#D61C4E", "#FEB139", "#FFF80A", "#E64848"]

print(clr.S + "Notebook Color Scheme: " + clr.E)
sns.palplot(sns.color_palette(my_colors))

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('/kaggle/input/shoe-dataset/MEN_SHOES.csv')

# %%
df.head()

# %%
df.columns

# %%
df.info()

# %%
# Replace special characters 

df['Current_Price'] = df['Current_Price'].str.replace('₹', '')
df['Current_Price'] = df['Current_Price'].str.replace(',', '')
df['How_Many_Sold'] = df['How_Many_Sold'].str.replace(',', '')

# %% [markdown]
# # **<span style="color:#E64848;">🥽Let's see what all we can explore in this dataset</span>**
#
# 1. Which Brand has max rating?
#
# 2. Which brand is sold the max?
#
# 3. Which is the most and least priced Product?
#
# 4. Which Brand sells costliest shoes?

# %% [markdown]
# ## **<span style="color:#FEB139;">1️⃣Which Brand has max rating?</span>**

# %%
max_rating = df['RATING'].max()
max_rating_brand = df.loc[df['RATING'] == max_rating, 'Brand_Name'].iloc[0]

print(max_rating_brand, ' has maximum rating of ', max_rating)

# %%
# --------------------Rating VS Brand Name------------------------

plt.figure(figsize = (40,20))
sns.catplot(x = 'RATING',
            y = 'Brand_Name',
            kind = "bar",
            height = 7,
            aspect = 2,            
            data = df.head(100)).set(title = "Rating vs Brand Name");
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# ## **<span style="color:#FEB139;">2️⃣Which brand is sold the max?</span>**

# %%
df['How_Many_Sold'] = df['How_Many_Sold'].astype(int)

# %%
max_shoes_sold = df['How_Many_Sold'].max()
max_sold_brand = df.loc[df['How_Many_Sold'] ==  max_shoes_sold, 'Brand_Name'].iloc[0]

print(max_sold_brand, ' sold maximum ', max_shoes_sold, 'Shoes')

# %%
min_shoes_sold = df['How_Many_Sold'].min()
min_sold_brand = df.loc[df['How_Many_Sold'] ==  min_shoes_sold, 'Brand_Name'].iloc[0]

print(min_sold_brand, ' sold least', min_shoes_sold, 'Shoes')

# %%
# --------------------Shoes sold VS Brand Name------------------------

plt.figure(figsize = (40,20))
sns.catplot(x = 'How_Many_Sold',
            y = 'Brand_Name',
            kind = "bar",
            height = 7,
            aspect = 2,            
            data = df.head(100)).set(title = "Rating vs Brand Name");
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# ## **<span style="color:#FEB139;">3️⃣Which is the most and least priced Product?</span>**

# %%
df['Current_Price'].unique()

# %%
df.dropna(axis = 0, inplace = True)

# %%
df['Current_Price'] = df['Current_Price'].astype(int)

# %%
min_shoes_price = df['Current_Price'].min()
min_priced_product = df.loc[df['Current_Price'] ==  min_shoes_price, 'Product_details'].iloc[0]

print(min_priced_product, ' are the least priced shoes, priced at - $',min_shoes_price )

# %%
max_shoes_price = df['Current_Price'].max()
max_priced_product = df.loc[df['Current_Price'] ==  max_shoes_price, 'Product_details'].iloc[0]

print(max_priced_product, ' are the least priced shoes, priced at - $',max_shoes_price )

# %%
# --------------------Product VS Price------------------------

plt.figure(figsize = (40,20))
sns.catplot(x = 'Current_Price',
            y = 'Product_details',
            kind = "bar",
            height = 7,
            aspect = 2,            
            data = df.head(100)).set(title = "Product vs Price");
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# ## **<span style="color:#FEB139;">4️⃣Which Brand sells costliest shoes?</span>**

# %%
max_shoes_price = df['Current_Price'].max()
max_priced_brand = df.loc[df['Current_Price'] ==  max_shoes_price, 'Brand_Name'].iloc[0]

print(max_priced_brand, ' have the most priced shoes at - $',max_shoes_price )

# %% [markdown]
# # **<span style="color:#cd486b;">🤘Conclusion</span>**
#
#
# **<span style="color:#000000;">This marks the end of 👞EDA: Shoe Dataset</span>**
#
# **<span style="color:#000000;"> Stay Tuned for more..</span>**
#
# **<span style="color:#000000;">Please share your feedback and suggestions and help me improve 😇 </span>**
