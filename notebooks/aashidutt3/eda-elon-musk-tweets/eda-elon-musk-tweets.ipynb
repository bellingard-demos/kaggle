# %% [markdown]
# <div style="width:100%;text-align: center;"> <img align=middle src="https://nypost.com/wp-content/uploads/sites/2/2022/04/elon-musk-funny-tweets.jpg?quality=75&strip=all&w=744" alt="Heat beating" style="height:366px;margin-top:3rem;"> </div>

# %% [markdown]
# # <h1 style='background:#1DA1F2; border:0; color:white'><center>🌟EDA: Elon Musk Tweets🌟</center></h1>

# %% [markdown]
# # **<span style="color:#31E1F7;">📰About the Dataset</span>**
#
# Elon Musk is an American business magnate. He was one of the founders of PayPal in the past, and the founder and/or co-founder Elon Musk is an American business magnate. He was one of the founders of PayPal in the past, and the founder and CEO of SpaceX, Tesla, SolarCity, OpenAI, Neuralink, and The Boring Company in the present. He is known as much for his extreme forward-thinking ideas and huge media presence as he is for his extremely business savvy.
#
# Musk is famously active on Twitter. This dataset contains all tweets made by @elonmusk, his official Twitter handle.
#
# # **<span style="color:#31E1F7;">📁About the files</span>**
#
# This dataset has the following features;
#
# > Date Created
#
# > Number of Likes
#
# > Source of Tweet
#
# > Tweets

# %%
# Imports

import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import plotly.express as px

# %%
#Environment check
import os
import warnings
warnings.filterwarnings("ignore")

# %%
#Custom Colors
class clr:
    S = '\033[1m' + '\033[96m'
    E = '\033[0m'
    
my_colors = ["#1DA1F2", "#31E1F7", "#400D51", "#D800A6", "#FF7777", "#CC3636"]

print(clr.S + "Notebook Color Scheme: " + clr.E)
sns.palplot(sns.color_palette(my_colors))

# %% [markdown]
# ## **<span style="color:#400D51;">📄Get the Dataset</span>**

# %%
df = pd.read_csv('/kaggle/input/elon-musk-tweets-dataset-17k/elonmusk.csv')

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %%
#Check for null values
df.isnull().any()

# %%
df.columns

# %% [markdown]
# # **<span style="color:#400D51;">🥽Let's see what all we can explore in this dataset</span>**
#
# > 1. Which tweet has maximum / minimum number of likes?
#
# > 2. Which sources are most popular for tweeting?
#
# > 3. What are the least and most number of likes?
#
# > 4. Does Date of tweet has something to say?

# %% [markdown]
# ## **<span style="color:#1DA1F2;">1️⃣Which tweet has maximum / minimum number of likes?</span>**

# %%
max_likes = df['Number of Likes'].max()
liked_tweet = df.loc[df['Number of Likes'] == max_likes, 'Tweets'].iloc[0]

print('"', liked_tweet , '" tweet got most likes i.e', max_likes, 'likes')

# %%
min_likes = df['Number of Likes'].min()
least_liked_tweet = df.loc[df['Number of Likes'] == min_likes, 'Tweets'].iloc[0]

print('"', least_liked_tweet , '" tweet got least likes i.e', min_likes, 'likes')

# %%
sorted_df = df.sort_values(by = "Number of Likes", ascending = False)
sorted_df = sorted_df.head(25)

fig = px.bar(sorted_df, x = "Tweets", y = "Number of Likes", color = "Number of Likes",
             color_continuous_scale = ["#E80F88", "#AF0171", "#790252", "#4C0033"])

fig.update_traces(marker = dict(line = dict(width = 2, color = "#F2F2F2")))
fig.update_layout(template = "plotly_dark", font = dict(family = "PT Sans", size = 16, color ="#EBC7E8"))
fig.update_xaxes(showticklabels = False) # Hide x axis ticks
fig.update_coloraxes(showscale=False)
fig.show()

## This snippet of code has been contributed by Matt OP

# %% [markdown]
# ## **<span style="color:#1DA1F2;">2️⃣Which sources are most popular for tweeting?</span>**

# %%
df['Source of Tweet'].value_counts()

# %%
df['Source of Tweet'].value_counts().plot(kind="bar",figsize=(15,8),title="Source of Tweet", color = my_colors[4])
plt.show()

# %% [markdown]
# ## **<span style="color:#1DA1F2;">3️⃣What are the least and most number of likes?</span>**

# %%
sorted_df['Number of Likes'].head(25).plot(kind = 'bar', figsize = (15,8), title = "Most number of likes", color = my_colors[3])
plt.show()

# %%
sorted_df = df.sort_values(by = "Number of Likes", ascending = True)
sorted_df['Number of Likes'].head(25).plot(kind = 'bar', figsize = (15,8), title = "Least number of likes", color = my_colors[4])
plt.show()

# %% [markdown]
# ## **<span style="color:#1DA1F2;">4️⃣Does Date of tweet has something to say?</span>**

# %% [markdown]
# ### **<span style="color:#400D51;">🗓When was the first tweet made?</span>**

# %%
date_sort = df.sort_values(by = "Date Created", ascending = True)
date_sort['Date Created']

# %%
print("First tweet was made on ",date_sort['Date Created'][17436 ] )

# %% [markdown]
# ### **<span style="color:#400D51;">🤔What was Musk's first tweet about?</span>**

# %%
first_tweet = date_sort['Date Created'][17436 ]
Tweet = date_sort.loc[date_sort['Date Created'] == first_tweet, 'Tweets'].iloc[0]

print("Elon Musk's first tweet was - ' ",Tweet, "Posted on - ", first_tweet )

# %% [markdown]
# # **<span style="color:#cd486b;">🤘Conclusion</span>**
#
# **<span style="color:#000000;">This is the end of 📱🔷EDA: Elon Musk Tweets</span>**
#
# **<span style="color:#000000;"> Stay Tuned for more..</span>**
#
# **<span style="color:#000000;">Please share your feedback and suggestions and help me improve 😇 </span>**

# %% [markdown]
# <div style="width:100%;text-align: center;"> <img align=middle src="https://m.economictimes.com/thumb/msid-91108370,width-1200,height-900,resizemode-4,imgsize-2222010/elon-musk_twitter-india_thumb-image_ettech.jpg" alt="Heat beating" style="height:366px;margin-top:3rem;"> </div>
