# %% [markdown]
# <div style="width:100%;text-align: center;"> <img align=middle src="https://c.tenor.com/Dyg_gZa4Vl4AAAAM/for-sale.gif" alt="Heat beating" style="height:366px;margin-top:3rem;"> </div>

# %% [markdown]
# # <h1 style='background:#F29393; border:0; color:white'><center>🏡EDA:USA Housing</center></h1>

# %% [markdown]
# # **<span style="color:#cd486b;">📰About the Dataset</span>**
#
# This dataset contains data related to the factors that affect housing prices in The United States.
#
# # **<span style="color:#cd486b;">📁About the files</span>**
#
# This dataset contains the following columns:
#
# > 'Avg. Area Income',
#
# > 'Avg. Area House Age',
#
# > 'Avg. Area Number of Rooms',
#
# > 'Avg. Area Number of Bedrooms',
#
# > 'Area Population',
#
# > 'Price',
#
# > 'Address'

# %%
# Imports
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Custom Colors
class clr:
    S = '\033[1m' + '\033[96m'
    E = '\033[0m'
    
my_colors = ["#554994", "#F675A8", "#F29393", "#FFCCB3", "#E64848"]

print(clr.S + "Notebook Color Scheme: " + clr.E)
sns.palplot(sns.color_palette(my_colors))

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('/kaggle/input/usa-housing/USA_Housing.csv')

# %%
df.head()

# %%
df.columns

# %% [markdown]
# ## **<span style="color:#cd486b;">📊Let's plot some data</span>**

# %%
sns.pairplot(data = df)
plt.savefig('save_as_a_png.png')

# %% [markdown]
# ## **<span style="color:#cd486b;">🤝Correlation</span>**

# %%
plt.figure(figsize = (15, 10))
sns.heatmap(df.corr(), annot = True, cmap = 'summer')
plt.savefig('heatmap.png')

# %% [markdown]
# # **<span style="color:#E64848;">🥽Let's see what all we can explore in this dataset</span>**
#
# > 1. Maximum income of people of the area
#
# > 2. Maximum and minimum house age
#
# > 3. Max and Min number of rooms
#
# > 4. Average area population
#
# > 5. Maximum and minimum price of a house

# %% [markdown]
# ## **<span style="color:#554994;">1️⃣Maximum and minimum income of people</span>**

# %%
income_min = df['Avg. Area Income'].min()
income_max = df['Avg. Area Income'].max()
print('Min income of people is - $', round(income_min),' while, Max income is - $', round(income_max))

# %%
# --------------------Price VS Avg Area Income------------------------

plt.figure(figsize = (40,20))
sns.catplot(x = 'Price',
            y = 'Avg. Area Income',
            kind = "bar",
            height = 7,
            aspect = 2,            
            data = df.head(100)).set(title = "Price vs Area Income");
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# ## **<span style="color:#554994;">2️⃣Maximum and minimum house age</span>**

# %%
age_min = df['Avg. Area House Age'].min()
age_max = df['Avg. Area House Age'].max()

print('Min age of house is -', round(age_min), 'Years. Max age of house is - ', round(age_max), 'Years')

# %%
plt.figure(figsize = (15,8))
House_age = round(df['Avg. Area House Age'])
House_age.head(20).plot(kind = 'bar', color = my_colors[2])
plt.xticks(rotation = 0)
plt.show()

# %%
# --------------------Price VS House Age------------------------

plt.figure(figsize = (40,20))
sns.catplot(x = 'Price',
            y = 'Avg. Area House Age',
            kind = "bar",
            height = 7,
            aspect = 2,            
            data = df.head(100)).set(title = "Price vs House Age");
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# ## **<span style="color:#554994;">3️⃣Max and Min number of rooms</span>**

# %%
rooms_min = df['Avg. Area Number of Rooms'].min()
rooms_max = df['Avg. Area Number of Rooms'].max()

print('Min rooms per house are -', round(age_min), 'while, Max rooms per house are - ', round(age_max))

# %%
# ------------------Price VS Number of Rooms----------------------------

plt.figure(figsize = (40,20))
sns.catplot(x = 'Price',
            y = 'Avg. Area Number of Rooms',
            kind = "bar",
            height = 7,
            aspect = 2,            
            data = df.head(100)).set(title = "Price vs Number of Rooms");
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# ## **<span style="color:#554994;">4️⃣Average area population</span>**

# %%
area_population = df['Area Population']
plt.figure(figsize=(15,8))
plt.plot(area_population, color= my_colors[4])

# %%
# ------------------Price VS Area Population----------------------------

plt.figure(figsize = (40,20))
sns.catplot(x = 'Price',
            y = 'Area Population',
            kind = "bar",
            height = 7,
            aspect = 2,            
            data = df.head(100)).set(title = "Price vs Area Population");
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# ## **<span style="color:#554994;">5️⃣Maximum and minimum price of a house</span>**

# %%
price_min = df['Price'].min()
price_max = df['Price'].max()

print('Min price of house is $ -', round(price_min), 'while, Max price of house is - ', round(price_max))

# %%
price = round(df['Price'])

plt.figure(figsize = (15,8))
price.head(20).plot(kind = 'bar', color = my_colors[3])
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# # **<span style="color:#F29393;">Conclusion</span>**
# ------------------------
#
# **<span style="color:#000000;">This is the end of 🏡EDA: USA Housing</span>**
#
# **<span style="color:#000000;"> Stay Tuned for more EDA Analysis</span>**
#
# **<span style="color:#000000;">Please share your feedback and suggestions and help me improve 😇 </span>**
