# %% [markdown]
# <div style="width:100%;text-align: center;"> <img align=middle src="https://images.unsplash.com/photo-1460881680858-30d872d5b530?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxzZWFyY2h8NHx8YW1lcmljYW4lMjBtb3ZpZXN8ZW58MHwwfDB8fA%3D%3D&auto=format&fit=crop&w=500&q=60" style="height:400px;margin-top:3rem;"> </div>

# %% [markdown]
# # <h1 style='background:#E56B6F; border:0; color:white'><center> 🎬EDA: List of All American Movies</center></h1>

# %% [markdown]
# # **<span style="color:#EAAC8B;">📰About the Dataset</span>**
#
# List of US movies released from 2008 to 2021.
#
# # **<span style="color:#EAAC8B;">📁About the files</span>**
#
# This dataset has 5 columns, namely:
#
# > Release_Date
#
# > Title
#
# > Production company name
#
# > Cast and crew
#
# > Genre

# %%
#Imports
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

#Custom Colors
class clr:
    S = '\033[1m' + '\033[96m'
    E = '\033[0m'
    
my_colors = ["#143F6B","#6D597A", "#B56576", "#E56B6F", "#EAAC8B"]

print(clr.S + "Notebook Color Scheme: " + clr.E)
sns.palplot(sns.color_palette(my_colors))

# %%
#Environment check
import os
import warnings
warnings.filterwarnings("ignore")

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('/kaggle/input/movies-list-of-all-american-movies-20082021/2008-2021_US_Movies.csv')

# %%
df.info()

# %%
df.describe()

# %%
df.columns

# %%
df.head()

# %% [markdown]
# # **<span style="color:#6D597A;">🥽Let's see what all we can explore in this dataset</span>**
#
# > 1. When was most movies released ?
#
# > 2. Relation between Genre and Titles
#
# > 3. Movie Release Date VS Titles
#
# > 4. Which Genre movies are most prefered?
#
# > 5. Which movie title made big name?
#
# > 6. Which Production Company made big name?

# %% [markdown]
# ## **<span style="color:#B56576;"> 1️⃣ When was most movies released ?</span>**

# %%
# When was most Movies released
max_release = df['Release_Date'].value_counts()
max_release

# %%
plt.figure(figsize=(15,8))
year_club = df.groupby(['Release_Date', 'Title']).Title.size().head(20).plot(kind = 'barh',color = my_colors[2])
plt.title('Titles Vs their Release Dates')
plt.legend()
plt.show()

# %% [markdown]
# **<span style="color:#E56B6F;">Most movie releases took place on 10 Sept 2021, followed by 12 Feb 2021.</span>**

# %% [markdown]
# ## **<span style="color:#B56576;"> 2️⃣ Relation between Genre and Titles</span>**

# %%
plt.figure(figsize=(15,8))
year_club = df.groupby(['Genre', 'Title']).Genre.size().head(20).plot(kind = 'barh',color = my_colors[3])
plt.title('Genre VS Titles')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (40,20))
sns.catplot(x = 'Genre',
            y = 'Title',
            kind = "strip",
            height = 7,
            aspect = 2,            
            data = df.head(100)).set(title = "Genre vs Title");
plt.show()

# %% [markdown]
# ## **<span style="color:#B56576;"> 3️⃣ Movie Release Date VS Titles</span>**

# %%
plt.figure(figsize= (15,8))
sns.stripplot(x="Release_Date", y="Title", data=df.head(50), jitter=0.5).set(title = "Release Date vs Title");

# %% [markdown]
# ## **<span style="color:#B56576;"> 4️⃣ Which Genre movies are most prefered?</span>**

# %%
from wordcloud import WordCloud

genre = df['Genre']

# Generate a word cloud 
wordcloud1 = WordCloud(collocation_threshold = 2,
                      collocations= True,
                      colormap="afmhot").generate(' '.join(df['Genre'].astype(str)))

# Generate plot
plt.figure(figsize = (15,8))
plt.imshow(wordcloud1, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ## **<span style="color:#B56576;"> 5️⃣ Which movie title made big name?</span>**

# %%
wordcloud2 = WordCloud(collocation_threshold = 2,
                      collocations= True,
                       colormap = 'RdYlGn'
                      ).generate(' '.join(df['Title']))

# Generate plot
plt.figure(figsize = (15,8))
plt.imshow(wordcloud2, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ## **<span style="color:#B56576;"> 6️⃣ Which Production Company made big name?</span>**

# %%
wordcloud2 = WordCloud(collocation_threshold = 2,
                      collocations= True,
                       colormap="Set2"
                      ).generate(' '.join(df['Production company'].astype(str)))

# Generate plot
plt.figure(figsize = (15,8))
plt.imshow(wordcloud2, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# # **<span style="color:#cd486b;">🤘Conclusion</span>**
#
#
# **<span style="color:#000000;">This marks the end of 🎬EDA: List of All American Movies</span>**
#
# **<span style="color:#000000;"> Stay Tuned for more..</span>**
#
# **<span style="color:#000000;">Please share your feedback and suggestions and help me improve 😇 </span>**
