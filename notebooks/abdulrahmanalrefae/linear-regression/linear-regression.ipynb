# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# from sklearn.linear_model import LinearRegression as lr
# from sklearn.model_selection import train_test_split

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ## Load the data you receive into a Pandas DataFrame

# %%
df = pd.read_csv('../input/heights-and-weights/data.csv')
df

# %% [markdown]
# ## Show the first five rows of the data set.

# %%
df.head(5)

# %% [markdown]
# ## Show the description and the info of the data set.

# %%
df.describe()

# %%
x = df['Height'].values
x

# %%
y = df['Weight'].values
y

# %%
plt.scatter(x, y, color='red')
plt.xlabel('Height')
plt.ylabel("Weight")
plt.title("relation")

# %%
X = x.reshape(-1,1)
X, len(X)

# %%
# !pip install -U scikit-learn

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y, train_size = .8, test_size = .2, random_state = 100)

# %%
x_train, len(x_train)

# %%
x_test, len(x_test)

# %%
plt.scatter(x_train, y_train, color='red')
plt.xlabel('Height')
plt.ylabel("Weight")
plt.title("relation")
plt.plot

# %%
y_train

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)

# %%
y_predict = lr.predict(x_test)
y_predict

# %%
lr.predict([[1.90]])

# %%
lr.score(x_test, y_test) * 100

# %%
y_predict = lr.predict(x_test)

# %%
plt.scatter(x_train, y_train, color='red')
plt.plot(x_test, y_predict)
plt.xlabel('Height')
plt.ylabel("Weight")
plt.title("relation")

# %%
lr.score(x_test, y_test)

# %%
plt.scatter(x,y)
plt.plot

# %% [markdown]
# ## conclusion
# - It is obvious there is a direct (linear) proportion between the weights and heights of an adult human.
# - The correlation seems to become less linear near the upper limit of the data set, but not enough to employ a different model here.
# - The more the hight rises in the graph the more weight rises up.
